# %%
import requests
import pandas as pd
import time
API_KEY = ''  # replace with your actual API key
BASE_URL = 'https://api.themoviedb.org/3'
base_image_url = 'https://image.tmdb.org/t/p/w500'

# %%
movie_id = 27205  # Inception

url = f'{BASE_URL}/movie/{movie_id}'
params = {
    'api_key': API_KEY,
    'language': 'en-US'
}

print("Requesting:", url)
response = requests.get(url, params=params)
print("Status Code:", response.status_code)

if response.status_code == 200:
    movie = response.json()
    print("Title:", movie['title'])
    print("Release Date:", movie['release_date'])
    print("Overview:", movie['overview'])
else:
    print("Error:", response.status_code)
    print("Full response:", response.text)
# Out:
# Requesting: https://api.themoviedb.org/3/movie/27205
# Status Code: 200
# Title: Inception
# Release Date: 2010-07-15
# Overview: Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person's idea into a target's subconscious.

# %%
def get_movie_details(movie_id):
    url = f"{BASE_URL}/movie/{movie_id}"
    params = {'api_key': API_KEY, 'language': 'en-US'}
    response = requests.get(url, params=params)
    return response.json() if response.status_code == 200 else None

# %%
def get_movie_credits(movie_id):
    url = f"{BASE_URL}/movie/{movie_id}/credits"
    params = {'api_key': API_KEY}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        cast = [member['name'] for member in data['cast'][:5]]  # Top 5 cast
        director = next((c['name'] for c in data['crew'] if c['job'] == 'Director'), None)
        return cast, director
    return [], None

# %%
def get_movie_keywords(movie_id):
    url = f"{BASE_URL}/movie/{movie_id}/keywords"
    params = {'api_key': API_KEY}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        return [k['name'] for k in data.get('keywords', [])]
    return []

# %%
movie_ids = [27205, 157336, 155, 299534, 603]  # Inception, Interstellar, Dark Knight, Endgame, The Matrix

# %%
movie_data = []

for movie_id in movie_ids:
    print(f"Fetching ID {movie_id}...")
    details = get_movie_details(movie_id)
    if not details:
        continue

    cast, director = get_movie_credits(movie_id)
    keywords = get_movie_keywords(movie_id)

    movie = {
        'id': details['id'],
        'title': details['title'],
        'overview': details.get('overview'),
        'genres': [g['name'] for g in details.get('genres', [])],
        'vote_average': details.get('vote_average'),
        'vote_count': details.get('vote_count'),
        'poster_path': details.get('poster_path'),
        'release_date': details.get('release_date'),
        'original_language': details.get('original_language'),
        'popularity': details.get('popularity'),
        'adult': details.get('adult'),
        'runtime': details.get('runtime'),
        'budget': details.get('budget'),
        'revenue': details.get('revenue'),
        'cast': cast,
        'director': director,
        'keywords': keywords
    }

    movie_data.append(movie)
    time.sleep(0.25)  # Be kind to the API
# Out:
# Fetching ID 27205...
# Fetching ID 157336...
# Fetching ID 155...
# Fetching ID 299534...
# Fetching ID 603...

# %%
df = pd.DataFrame(movie_data)

# %%
base_image_url = 'https://image.tmdb.org/t/p/w500'
df['poster_url'] = df['poster_path'].apply(lambda path: base_image_url + path if pd.notnull(path) else None)

# %%
df.head()
# Out:
#        id              title  \
# 0   27205          Inception
# 1  157336       Interstellar
# 2     155    The Dark Knight
# 3  299534  Avengers: Endgame
# 4     603         The Matrix
#
#                                             overview  \
# 0  Cobb, a skilled thief who commits corporate es...
# 1  The adventures of a group of explorers who mak...
# 2  Batman raises the stakes in his war on crime. ...
# 3  After the devastating events of Avengers: Infi...
# 4  Set in the 22nd century, The Matrix tells the ...
#
#                                  genres  vote_average  vote_count  \
# 0  [Action, Science Fiction, Adventure]         8.369       37298
# 1   [Adventure, Drama, Science Fiction]         8.453       36880
# 2      [Drama, Action, Crime, Thriller]         8.519       33667
# 3  [Adventure, Science Fiction, Action]         8.238       26202
# 4             [Action, Science Fiction]         8.200       26231
#
#                         poster_path release_date original_language  \
# 0  /ljsZTbVsrQSqZgWeep2B1QiDKuh.jpg   2010-07-15                en
# 1  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg   2014-11-05                en
# 2  /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16                en
# 3  /ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg   2019-04-24                en
# 4  /dXNAPwY7VrqMAo51EKhhCJfaGb5.jpg   1999-03-31                en
#
#    popularity  adult  runtime     budget     revenue  \
# 0     27.8694  False      148  160000000   839030630
# 1     46.0951  False      169  165000000   746606706
# 2     31.0077  False      152  185000000  1004558444
# 3     22.6136  False      181  356000000  2799439100
# 4     28.7297  False      136   63000000   463517383
#
#                                                 cast           director  \
# 0  [Leonardo DiCaprio, Joseph Gordon-Levitt, Ken ...  Christopher Nolan
# 1  [Matthew McConaughey, Anne Hathaway, Michael C...  Christopher Nolan
# 2  [Christian Bale, Heath Ledger, Aaron Eckhart, ...  Christopher Nolan
# 3  [Robert Downey Jr., Chris Evans, Mark Ruffalo,...          Joe Russo
# 4  [Keanu Reeves, Laurence Fishburne, Carrie-Anne...     Lana Wachowski
#
#                                             keywords  \
# 0  [rescue, mission, dreams, airplane, paris, fra...
# 1  [rescue, future, spacecraft, race against time...
# 2  [joker, sadism, chaos, secret identity, crime ...
# 3  [superhero, time travel, space travel, time ma...
# 4  [man vs machine, martial arts, dreams, artific...
#
#                                           poster_url
# 0  https://image.tmdb.org/t/p/w500/ljsZTbVsrQSqZg...
# 1  https://image.tmdb.org/t/p/w500/gEU2QniE6E77NI...
# 2  https://image.tmdb.org/t/p/w500/qJ2tW6WMUDux91...
# 3  https://image.tmdb.org/t/p/w500/ulzhLuWrPK07P1...
# 4  https://image.tmdb.org/t/p/w500/dXNAPwY7VrqMAo...

# %%
def discover_movies(page=1, release_from='2000-01-01', release_to='2025-12-31'):
    url = f"{BASE_URL}/discover/movie"
    params = {
        'api_key': API_KEY,
        'language': 'en-US',
        'sort_by': 'popularity.desc',
        'include_adult': False,
        'include_video': False,
        'page': page,
        'release_date.gte': release_from,
        'release_date.lte': release_to,
        'vote_count.gte': 100
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()['results']
    else:
        print("Error:", response.status_code, response.text)
        return []

# %%
def get_movie_details(movie_id):
    url = f"{BASE_URL}/movie/{movie_id}"
    params = {'api_key': API_KEY, 'language': 'en-US'}
    response = requests.get(url, params=params)
    return response.json() if response.status_code == 200 else None

def get_movie_credits(movie_id):
    url = f"{BASE_URL}/movie/{movie_id}/credits"
    params = {'api_key': API_KEY}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        cast = [member['name'] for member in data['cast'][:5]]
        director = next((c['name'] for c in data['crew'] if c['job'] == 'Director'), None)
        return cast, director
    return [], None

def get_movie_keywords(movie_id):
    url = f"{BASE_URL}/movie/{movie_id}/keywords"
    params = {'api_key': API_KEY}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        return [k['name'] for k in data.get('keywords', [])]
    return []

# %%
all_movies_raw = []
for page in range(1, 6):  # Adjust page range for more movies (up to 500)
    print(f"Fetching page {page}...")
    results = discover_movies(page=page)
    all_movies_raw.extend(results)
    time.sleep(0.25)
# Out:
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...

# %%
def enrich_movie_data(movie):
    movie_id = movie['id']
    print(f"Enriching: {movie['title']} ({movie_id})")

    details = get_movie_details(movie_id)
    cast, director = get_movie_credits(movie_id)
    keywords = get_movie_keywords(movie_id)

    return {
        'id': movie['id'],
        'title': movie['title'],
        'overview': movie.get('overview'),
        'genres': [g['name'] for g in details.get('genres', [])] if details else [],
        'vote_average': movie.get('vote_average'),
        'vote_count': movie.get('vote_count'),
        'release_date': movie.get('release_date'),
        'original_language': movie.get('original_language'),
        'popularity': movie.get('popularity'),
        'adult': movie.get('adult'),
        'runtime': details.get('runtime') if details else None,
        'budget': details.get('budget') if details else None,
        'revenue': details.get('revenue') if details else None,
        'cast': cast,
        'director': director,
        'keywords': keywords,
        'poster_url': base_image_url + movie['poster_path'] if movie.get('poster_path') else None
    }

# %%
enriched_movies = []
for movie in all_movies_raw:
    enriched = enrich_movie_data(movie)
    enriched_movies.append(enriched)
    time.sleep(0.25)
# Out:
# Enriching: A Minecraft Movie (950387)
# Enriching: Cleaner (1125899)
# Enriching: Captain America: Brave New World (822119)
# Enriching: A Working Man (1197306)
# Enriching: Ask Me What You Want (1252309)
# Enriching: Mickey 17 (696506)
# Enriching: Moana 2 (1241982)
# Enriching: Mufasa: The Lion King (762509)
# Enriching: Black Bag (1233575)
# Enriching: Sonic the Hedgehog 3 (939243)
# Enriching: The Life List (1254786)
# Enriching: Flight Risk (1126166)
# Enriching: Snow White (447273)
# Enriching: Batman Ninja vs. Yakuza League (1297763)
# Enriching: Counterattack (1356039)
# Enriching: The Gorge (950396)
# Enriching: Demon City (1405338)
# Enriching: Holland (257094)
# Enriching: Kraven the Hunter (539972)
# Enriching: Amaran (927342)
# Enriching: Venom: The Last Dance (912649)
# Enriching: Gladiator II (558449)
# Enriching: Memoir of a Snail (1064486)
# Enriching: Companion (1084199)
# Enriching: The Monkey (1124620)
# Enriching: Flow (823219)
# Enriching: Panda Plan (1160956)
# Enriching: Despicable Me 4 (519182)
# Enriching: Deadpool & Wolverine (533535)
# Enriching: The Wild Robot (1184918)
# Enriching: Solo Leveling -ReAwakening- (1357633)
# Enriching: Inside Out 2 (1022789)
# Enriching: My Fault (1010581)
# Enriching: The Electric State (777443)
# Enriching: xXx (7451)
# Enriching: The Substance (933260)
# Enriching: Anora (1064213)
# Enriching: Presence (1140535)
# Enriching: Dog Man (774370)
# Enriching: Love Hurts (1226406)
# Enriching: The Godfather (238)
# Enriching: Alarum (1249289)
# Enriching: Henry Danger: The Movie (926670)
# Enriching: Last Breath (972533)
# Enriching: Interstellar (157336)
# Enriching: My Fault: London (1294203)
# Enriching: The Shawshank Redemption (278)
# Enriching: Elevation (1035048)
# Enriching: Squad 36 (1230208)
# Enriching: Red One (845781)
# Enriching: Your Fault (1156593)
# Enriching: Heretic (1138194)
# Enriching: Wicked (402431)
# Enriching: Apocalypse Z: The Beginning of the End (1118031)
# Enriching: The Chronicles of Narnia: The Lion, the Witch and the Wardrobe (411)
# Enriching: Absolution (974453)
# Enriching: Paddington in Peru (516729)
# Enriching: Spirited Away (129)
# Enriching: 365 Days: This Day (829557)
# Enriching: Sniper: The Last Stand (1410082)
# Enriching: Avengers: Infinity War (299536)
# Enriching: Back in Action (993710)
# Enriching: Nosferatu (426063)
# Enriching: Miraculous World: London, At the Edge of Time (1147416)
# Enriching: Fast X (385687)
# Enriching: Devara : Part 1 (811941)
# Enriching: Top Gun: Maverick (361743)
# Enriching: Blade Runner 2049 (335984)
# Enriching: The Avengers (24428)
# Enriching: Terrifier 3 (1034541)
# Enriching: Room in Rome (48650)
# Enriching: Bad Boys: Ride or Die (573435)
# Enriching: The Gardener (1255788)
# Enriching: The Lord of the Rings: The War of the Rohirrim (839033)
# Enriching: Smile 2 (1100782)
# Enriching: The Dark Knight (155)
# Enriching: Harry Potter and the Philosopher's Stone (671)
# Enriching: Avatar (19995)
# Enriching: Titanic (597)
# Enriching: Pleasure (592695)
# Enriching: Parthenope (1109255)
# Enriching: Five Nights at Freddy's (507089)
# Enriching: Spider-Man: No Way Home (634649)
# Enriching: Alien: Romulus (945961)
# Enriching: The Matrix (603)
# Enriching: Werewolves (970450)
# Enriching: Howl's Moving Castle (4935)
# Enriching: Spider-Man: Across the Spider-Verse (569094)
# Enriching: Shrek (808)
# Enriching: Conclave (974576)
# Enriching: Dune: Part Two (693134)
# Enriching: The Maze Runner (198663)
# Enriching: Survive (1196470)
# Enriching: Dirty Angels (1043905)
# Enriching: Fight Club (550)
# Enriching: Novocaine (1195506)
# Enriching: John Wick: Chapter 4 (603692)
# Enriching: Oppenheimer (872585)
# Enriching: Gladiator (98)
# Enriching: Inception (27205)

# %%
df = pd.DataFrame(enriched_movies)
df = df[[
    'id', 'title', 'overview', 'genres', 'vote_average', 'vote_count',
    'release_date', 'original_language', 'popularity', 'adult',
    'runtime', 'budget', 'revenue', 'cast', 'director', 'keywords', 'poster_url'
]]
df
# Out:
#          id                             title  \
# 0    950387                 A Minecraft Movie
# 1   1125899                           Cleaner
# 2    822119  Captain America: Brave New World
# 3   1197306                     A Working Man
# 4   1252309              Ask Me What You Want
# ..      ...                               ...
# 95  1195506                         Novocaine
# 96   603692              John Wick: Chapter 4
# 97   872585                       Oppenheimer
# 98       98                         Gladiator
# 99    27205                         Inception
#
#                                              overview  \
# 0   Four misfits find themselves struggling with o...
# 1   When a group of radical activists take over an...
# 2   After meeting with newly elected U.S. Presiden...
# 3   Levon Cade left behind a decorated military ca...
# 4   After his father's death, Eric Zimmerman trave...
# ..                                                ...
# 95  When the girl of his dreams is kidnapped, ever...
# 96  With the price on his head ever increasing, Jo...
# 97  The story of J. Robert Oppenheimer's role in t...
# 98  After the death of Emperor Marcus Aurelius, hi...
# 99  Cobb, a skilled thief who commits corporate es...
#
#                                   genres  vote_average  vote_count  \
# 0   [Family, Comedy, Adventure, Fantasy]         6.100         295
# 1                     [Action, Thriller]         6.517         174
# 2    [Action, Thriller, Science Fiction]         6.091        1232
# 3              [Action, Crime, Thriller]         6.467         151
# 4                       [Romance, Drama]         5.681         119
# ..                                   ...           ...         ...
# 95            [Action, Comedy, Thriller]         7.014         176
# 96             [Action, Thriller, Crime]         7.721        6956
# 97                      [Drama, History]         8.067       10063
# 98            [Action, Drama, Adventure]         8.218       19545
# 99  [Action, Science Fiction, Adventure]         8.400       37298
#
#    release_date original_language  popularity  adult  runtime     budget  \
# 0    2025-03-31                en   1022.7906  False      101  150000000
# 1    2025-02-19                en    343.3057  False       96          0
# 2    2025-02-12                en    339.0809  False      119  180000000
# 3    2025-03-26                en    293.7838  False      116   40000000
# 4    2024-11-29                es    286.5930  False        0          0
# ..          ...               ...         ...    ...      ...        ...
# 95   2025-03-12                en     29.7101  False      109   18000000
# 96   2023-03-22                en     30.5829  False      170   90000000
# 97   2023-07-19                en     27.7046  False      181  100000000
# 98   2000-05-04                en     29.9042  False      155  103000000
# 99   2010-07-15                en     27.8694  False      148  160000000
#
#       revenue                                               cast  \
# 0   313453003  [Jason Momoa, Jack Black, Sebastian Eugene Han...
# 1           0  [Daisy Ridley, Clive Owen, Taz Skylar, Flavia ...
# 2   411409721  [Anthony Mackie, Harrison Ford, Danny Ramirez,...
# 3    44417000  [Jason Statham, David Harbour, Michael Peña, J...
# 4           0  [Gabriela Andrada, Mario Ermito, Celia Freijei...
# ..        ...                                                ...
# 95   32254000  [Jack Quaid, Amber Midthunder, Ray Nicholson, ...
# 96  440157245  [Keanu Reeves, Donnie Yen, Bill Skarsgård, Ian...
# 97  952000000  [Cillian Murphy, Emily Blunt, Matt Damon, Robe...
# 98  465361176  [Russell Crowe, Joaquin Phoenix, Connie Nielse...
# 99  839030630  [Leonardo DiCaprio, Joseph Gordon-Levitt, Ken ...
#
#              director                                           keywords  \
# 0          Jared Hess  [friendship, surrealism, exploration, portal, ...
# 1     Martin Campbell                                                 []
# 2         Julius Onah  [hero, superhero, revenge, aftercreditsstinger...
# 3          David Ayer  [based on novel or book, kidnapping, vigilante...
# 4       Lucía Alemany  [spain, based on novel or book, woman director...
# ..                ...                                                ...
# 95           Dan Berk  [pain, dark comedy, bank robbery, held hostage...
# 96     Chad Stahelski  [new york city, martial arts, berlin, germany,...
# 97  Christopher Nolan  [husband wife relationship, based on novel or ...
# 98       Ridley Scott  [epic, gladiator, rome, italy, arena, senate, ...
# 99  Christopher Nolan  [rescue, mission, dreams, airplane, paris, fra...
#
#                                            poster_url
# 0   https://image.tmdb.org/t/p/w500/yFHHfHcUgGAxzi...
# 1   https://image.tmdb.org/t/p/w500/mwzDApMZAGeYCE...
# 2   https://image.tmdb.org/t/p/w500/pzIddUEMWhWzfv...
# 3   https://image.tmdb.org/t/p/w500/6FRFIogh3zFnVW...
# 4   https://image.tmdb.org/t/p/w500/76qnVxU2rPdVvi...
# ..                                                ...
# 95  https://image.tmdb.org/t/p/w500/xmMHGz9dVRaMY6...
# 96  https://image.tmdb.org/t/p/w500/vZloFAK7NmvMGK...
# 97  https://image.tmdb.org/t/p/w500/8Gxv8gSFCU0XGD...
# 98  https://image.tmdb.org/t/p/w500/ty8TGRuvJLPUmA...
# 99  https://image.tmdb.org/t/p/w500/ljsZTbVsrQSqZg...
#
# [100 rows x 17 columns]

# %%
all_batches = []

for batch_num in range(1, 6):  # 5 batches = 5000 movies
    print(f"\n🚀 Batch {batch_num}: Fetching pages {((batch_num - 1) * 50 + 1)} to {batch_num * 50}")
    
    all_movies_raw = []
    for page in range((batch_num - 1) * 50 + 1, batch_num * 50 + 1):
        print(f"Fetching page {page}...")
        results = discover_movies(page=page)
        all_movies_raw.extend(results)
        time.sleep(0.25)

    enriched_movies = []
    for movie in all_movies_raw:
        enriched = enrich_movie_data(movie)
        enriched_movies.append(enriched)
        time.sleep(0.25)
    
    df_batch = pd.DataFrame(enriched_movies)
    
    df_batch = df_batch[[
        'id', 'title', 'overview', 'genres', 'vote_average', 'vote_count',
        'release_date', 'original_language', 'popularity', 'adult',
        'runtime', 'budget', 'revenue', 'cast', 'director', 'keywords', 'poster_url'
    ]]
    
    # Save this batch to CSV
    filename = f"movies_batch_{batch_num}.csv"
    df_batch.to_csv(filename, index=False)
    print(f"✅ Saved batch {batch_num} to {filename}")
    
    # Save in memory too if you want to combine later
    all_batches.append(df_batch)
# Out:
# 🚀 Batch 1: Fetching pages 1 to 50
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# Fetching page 11...
# Fetching page 12...
# Fetching page 13...
# Fetching page 14...
# Fetching page 15...
# Fetching page 16...
# Fetching page 17...
# Fetching page 18...
# Fetching page 19...
# Fetching page 20...
# Fetching page 21...
# Fetching page 22...
# Fetching page 23...
# Fetching page 24...
# Fetching page 25...
# Fetching page 26...
# Fetching page 27...
# Fetching page 28...
# Fetching page 29...
# Fetching page 30...
# Fetching page 31...
# Fetching page 32...
# Fetching page 33...
# Fetching page 34...
# Fetching page 35...
# Fetching page 36...
# Fetching page 37...
# Fetching page 38...
# Fetching page 39...
# Fetching page 40...
# Fetching page 41...
# Fetching page 42...
# Fetching page 43...
# Fetching page 44...
# Fetching page 45...
# Fetching page 46...
# Fetching page 47...
# Fetching page 48...
# Fetching page 49...
# Fetching page 50...
# Enriching: A Minecraft Movie (950387)
# Enriching: Cleaner (1125899)
# Enriching: Captain America: Brave New World (822119)
# Enriching: A Working Man (1197306)
# Enriching: Ask Me What You Want (1252309)
# Enriching: Mickey 17 (696506)
# Enriching: Moana 2 (1241982)
# Enriching: Mufasa: The Lion King (762509)
# Enriching: Black Bag (1233575)
# Enriching: Sonic the Hedgehog 3 (939243)
# Enriching: The Life List (1254786)
# Enriching: Flight Risk (1126166)
# Enriching: Snow White (447273)
# Enriching: Batman Ninja vs. Yakuza League (1297763)
# Enriching: Counterattack (1356039)
# Enriching: The Gorge (950396)
# Enriching: Demon City (1405338)
# Enriching: Holland (257094)
# Enriching: Kraven the Hunter (539972)
# Enriching: Amaran (927342)
# Enriching: Venom: The Last Dance (912649)
# Enriching: Gladiator II (558449)
# Enriching: Memoir of a Snail (1064486)
# Enriching: Companion (1084199)
# Enriching: The Monkey (1124620)
# Enriching: Flow (823219)
# Enriching: Panda Plan (1160956)
# Enriching: Despicable Me 4 (519182)
# Enriching: Deadpool & Wolverine (533535)
# Enriching: The Wild Robot (1184918)
# Enriching: Solo Leveling -ReAwakening- (1357633)
# Enriching: Inside Out 2 (1022789)
# Enriching: My Fault (1010581)
# Enriching: The Electric State (777443)
# Enriching: xXx (7451)
# Enriching: The Substance (933260)
# Enriching: Anora (1064213)
# Enriching: Presence (1140535)
# Enriching: Dog Man (774370)
# Enriching: Love Hurts (1226406)
# Enriching: The Godfather (238)
# Enriching: Alarum (1249289)
# Enriching: Henry Danger: The Movie (926670)
# Enriching: Last Breath (972533)
# Enriching: Interstellar (157336)
# Enriching: My Fault: London (1294203)
# Enriching: The Shawshank Redemption (278)
# Enriching: Elevation (1035048)
# Enriching: Squad 36 (1230208)
# Enriching: Red One (845781)
# Enriching: Your Fault (1156593)
# Enriching: Heretic (1138194)
# Enriching: Wicked (402431)
# Enriching: Apocalypse Z: The Beginning of the End (1118031)
# Enriching: The Chronicles of Narnia: The Lion, the Witch and the Wardrobe (411)
# Enriching: Absolution (974453)
# Enriching: Paddington in Peru (516729)
# Enriching: Spirited Away (129)
# Enriching: 365 Days: This Day (829557)
# Enriching: Sniper: The Last Stand (1410082)
# Enriching: Avengers: Infinity War (299536)
# Enriching: Back in Action (993710)
# Enriching: Nosferatu (426063)
# Enriching: Miraculous World: London, At the Edge of Time (1147416)
# Enriching: Fast X (385687)
# Enriching: Devara : Part 1 (811941)
# Enriching: Top Gun: Maverick (361743)
# Enriching: Blade Runner 2049 (335984)
# Enriching: The Avengers (24428)
# Enriching: Terrifier 3 (1034541)
# Enriching: Room in Rome (48650)
# Enriching: Bad Boys: Ride or Die (573435)
# Enriching: The Gardener (1255788)
# Enriching: The Lord of the Rings: The War of the Rohirrim (839033)
# Enriching: Smile 2 (1100782)
# Enriching: The Dark Knight (155)
# Enriching: Harry Potter and the Philosopher's Stone (671)
# Enriching: Avatar (19995)
# Enriching: Titanic (597)
# Enriching: Pleasure (592695)
# Enriching: Parthenope (1109255)
# Enriching: Five Nights at Freddy's (507089)
# Enriching: Spider-Man: No Way Home (634649)
# Enriching: Alien: Romulus (945961)
# Enriching: The Matrix (603)
# Enriching: Werewolves (970450)
# Enriching: Howl's Moving Castle (4935)
# Enriching: Spider-Man: Across the Spider-Verse (569094)
# Enriching: Shrek (808)
# Enriching: Conclave (974576)
# Enriching: Dune: Part Two (693134)
# Enriching: The Maze Runner (198663)
# Enriching: Survive (1196470)
# Enriching: Dirty Angels (1043905)
# Enriching: Fight Club (550)
# Enriching: Novocaine (1195506)
# Enriching: John Wick: Chapter 4 (603692)
# Enriching: Oppenheimer (872585)
# Enriching: Gladiator (98)
# Enriching: Inception (27205)
# Enriching: Coco (354912)
# Enriching: Azrael (1029235)
# Enriching: Inception (27205)
# Enriching: Babygirl (1097549)
# Enriching: Coraline (14836)
# Enriching: Conclave (974576)
# Enriching: Wolf Man (710295)
# Enriching: Transformers One (698687)
# Enriching: The Super Mario Bros. Movie (502356)
# Enriching: The Conjuring (138843)
# Enriching: The Help (50014)
# Enriching: Carry-On (1005331)
# Enriching: Avatar: The Way of Water (76600)
# Enriching: Parasite (496243)
# Enriching: Never Let Go (814889)
# Enriching: Hotel Desire (82023)
# Enriching: Spider-Man: Into the Spider-Verse (324857)
# Enriching: Puss in Boots: The Last Wish (315162)
# Enriching: The Lord of the Rings: The Fellowship of the Ring (120)
# Enriching: The Garfield Movie (748783)
# Enriching: Godzilla x Kong: The New Empire (823464)
# Enriching: The Lord of the Rings: The Return of the King (122)
# Enriching: Dune (438631)
# Enriching: The Lion King (8587)
# Enriching: Your Name. (372058)
# Enriching: Ne Zha 2 (980477)
# Enriching: Tombstone (11969)
# Enriching: Furiosa: A Mad Max Saga (786892)
# Enriching: Paprika (50270)
# Enriching: Schindler's List (424)
# Enriching: TRON: Legacy (20526)
# Enriching: Migration (940551)
# Enriching: Inside Out (150540)
# Enriching: Top Gun (744)
# Enriching: Pirates of the Caribbean: The Curse of the Black Pearl (22)
# Enriching: The Lion King II: Simba's Pride (9732)
# Enriching: Snow White and the Seven Dwarfs (408)
# Enriching: Kingdom of the Planet of the Apes (653346)
# Enriching: Kingdom IV: Return of the Great General (1241320)
# Enriching: Heat (949)
# Enriching: The Beekeeper (866398)
# Enriching: Toy Story (862)
# Enriching: Big Hero 6 (177572)
# Enriching: Harry Potter and the Chamber of Secrets (672)
# Enriching: My Neighbor Totoro (8392)
# Enriching: Sonic the Hedgehog 2 (675353)
# Enriching: Venom (335983)
# Enriching: Avengers: Endgame (299534)
# Enriching: Den of Thieves 2: Pantera (604685)
# Enriching: Harry Potter and the Goblet of Fire (674)
# Enriching: Pulp Fiction (680)
# Enriching: The Lion King (420818)
# Enriching: Elemental (976573)
# Enriching: Twilight (8966)
# Enriching: Barbie (346698)
# Enriching: Forrest Gump (13)
# Enriching: The Wolf of Wall Street (106646)
# Enriching: Harry Potter and the Prisoner of Azkaban (673)
# Enriching: Wallace & Gromit: Vengeance Most Fowl (929204)
# Enriching: A Quiet Place: Day One (762441)
# Enriching: Fifty Shades of Grey (216015)
# Enriching: Ratatouille (2062)
# Enriching: Transformers: Rise of the Beasts (667538)
# Enriching: Zootopia (269149)
# Enriching: Aftermath (1081012)
# Enriching: Den of Thieves (449443)
# Enriching: Harry Potter and the Order of the Phoenix (675)
# Enriching: The Equalizer (156022)
# Enriching: After (537915)
# Enriching: Frozen (109445)
# Enriching: Tangled (38757)
# Enriching: I'm Still Here (1000837)
# Enriching: Mission: Impossible - Dead Reckoning Part One (575264)
# Enriching: The Godfather Part II (240)
# Enriching: Whiplash (244786)
# Enriching: The Karate Kid (38575)
# Enriching: Below Her Mouth (370663)
# Enriching: Se7en (807)
# Enriching: Armor (1182387)
# Enriching: Bridget Jones: Mad About the Boy (1272149)
# Enriching: Abigail (1111873)
# Enriching: The Hangover (18785)
# Enriching: Wrath of Man (637649)
# Enriching: IF (639720)
# Enriching: Lilo & Stitch (11544)
# Enriching: Fury (228150)
# Enriching: Better Man (799766)
# Enriching: Hacksaw Ridge (324786)
# Enriching: Final Destination (9532)
# Enriching: Harry Potter and the Deathly Hallows: Part 1 (12444)
# Enriching: Spider-Man (557)
# Enriching: Hereditary (493922)
# Enriching: Civil War (929590)
# Enriching: The Batman (414906)
# Enriching: Arcadian (1051896)
# Enriching: Fifty Shades Freed (337167)
# Enriching: Harry Potter and the Deathly Hallows: Part 2 (12445)
# Enriching: Iron Man (1726)
# Enriching: The Passion of the Christ (615)
# Enriching: Avengers: Age of Ultron (99861)
# Enriching: Mad Max: Fury Road (76341)
# Enriching: Speak No Evil (1114513)
# Enriching: The Count of Monte Cristo (1084736)
# Enriching: Train to Busan (396535)
# Enriching: The Lord of the Rings: The Two Towers (121)
# Enriching: The Notebook (11036)
# Enriching: Spider-Man: Homecoming (315635)
# Enriching: The Green Mile (497)
# Enriching: Beauty and the Beast (321612)
# Enriching: Bagman (978796)
# Enriching: Shrek 2 (809)
# Enriching: Ice Age (425)
# Enriching: Winnie-the-Pooh: Blood and Honey 2 (1079485)
# Enriching: Talk to Me (1008042)
# Enriching: Finding Nemo (12)
# Enriching: Gone Girl (210577)
# Enriching: One of Them Days (1280672)
# Enriching: Road House (359410)
# Enriching: Jurassic World Dominion (507086)
# Enriching: My Hero Academia: You're Next (1159311)
# Enriching: Wonder Woman (297762)
# Enriching: Sing: Thriller (1371727)
# Enriching: Anyone But You (1072790)
# Enriching: Encanto (568124)
# Enriching: Monsters, Inc. (585)
# Enriching: The Crow (957452)
# Enriching: Alien (348)
# Enriching: A Complete Unknown (661539)
# Enriching: Tarot (719221)
# Enriching: The Hunger Games: Mockingjay - Part 1 (131631)
# Enriching: Black Panther: Wakanda Forever (505642)
# Enriching: Shutter Island (11324)
# Enriching: Jurassic World (135397)
# Enriching: The Meg (345940)
# Enriching: La La Land (313369)
# Enriching: Guardians of the Galaxy Vol. 3 (447365)
# Enriching: Black Panther (284054)
# Enriching: Ferry 2 (1276945)
# Enriching: Ne Zha (615453)
# Enriching: Final Destination 5 (55779)
# Enriching: Pirates of the Caribbean: Dead Man's Chest (58)
# Enriching: World War Z (72190)
# Enriching: Godzilla Minus One (940721)
# Enriching: Beetlejuice Beetlejuice (917496)
# Enriching: The Handmaiden (290098)
# Enriching: The Next 365 Days (829560)
# Enriching: The Platform 2 (1125510)
# Enriching: Subservience (1064028)
# Enriching: 28 Days Later (170)
# Enriching: Harry Potter and the Half-Blood Prince (767)
# Enriching: Deadpool (293660)
# Enriching: Princess Mononoke (128)
# Enriching: Prisoners (146233)
# Enriching: The Accountant (302946)
# Enriching: Mulan (10674)
# Enriching: Sonic the Hedgehog (454626)
# Enriching: Up (14160)
# Enriching: Iron Man 2 (10138)
# Enriching: Fast & Furious Presents: Hobbs & Shaw (384018)
# Enriching: The Truman Show (37165)
# Enriching: How to Train Your Dragon (10191)
# Enriching: Joker (475557)
# Enriching: Cash Out (1116490)
# Enriching: The Hobbit: The Battle of the Five Armies (122917)
# Enriching: Star Wars (11)
# Enriching: The Fall Guy (746036)
# Enriching: Cinderella (11224)
# Enriching: The Terminator (218)
# Enriching: The Good, the Bad and the Ugly (429)
# Enriching: The Witcher: Sirens of the Deep (1203329)
# Enriching: The Boy and the Heron (508883)
# Enriching: Spellbound (592983)
# Enriching: The Twilight Saga: Breaking Dawn - Part 2 (50620)
# Enriching: Shang-Chi and the Legend of the Ten Rings (566525)
# Enriching: Thor: Ragnarok (284053)
# Enriching: Doctor Strange in the Multiverse of Madness (453395)
# Enriching: Luca (508943)
# Enriching: Geostorm (274855)
# Enriching: The Hunger Games: The Ballad of Songbirds & Snakes (695721)
# Enriching: The Pursuit of Happyness (1402)
# Enriching: Cruella (337404)
# Enriching: Maleficent (102651)
# Enriching: Borderlands (365177)
# Enriching: Good Will Hunting (489)
# Enriching: Final Destination 2 (9358)
# Enriching: Saving Private Ryan (857)
# Enriching: Hijack 1971 (1147710)
# Enriching: Jumanji: Welcome to the Jungle (353486)
# Enriching: Cinderella (150689)
# Enriching: Captain America: Civil War (271110)
# Enriching: Wonka (787699)
# Enriching: Wish (1022796)
# Enriching: Star Trek: Section 31 (1114894)
# Enriching: Prey (1129598)
# Enriching: Dogman (944401)
# Enriching: Twisters (718821)
# Enriching: GoodFellas (769)
# Enriching: Furious 7 (168259)
# Enriching: Caligula (9453)
# Enriching: Miraculous World: Paris, Tales of Shadybug and Claw Noir (1147400)
# Enriching: Poor Things (792307)
# Enriching: Call Me by Your Name (398818)
# Enriching: Project Silence (726139)
# Enriching: Toy Story 2 (863)
# Enriching: Spider-Man 3 (559)
# Enriching: M3GAN (536554)
# Enriching: The Equalizer 3 (926393)
# Enriching: Back to the Future (105)
# Enriching: The Little Mermaid (447277)
# Enriching: The Price of Money: A Largo Winch Adventure (1000075)
# Enriching: Grown Ups (38365)
# Enriching: White Chicks (12153)
# Enriching: Pirates of the Caribbean: On Stranger Tides (1865)
# Enriching: WALL·E (10681)
# Enriching: Oddity (1216191)
# Enriching: Scarface (111)
# Enriching: BLUE LOCK THE MOVIE -EPISODE NAGI- (1104844)
# Enriching: The Hunger Games: Catching Fire (101299)
# Enriching: Terminator 2: Judgment Day (280)
# Enriching: Sisu (840326)
# Enriching: Tron (97)
# Enriching: 12 Angry Men (389)
# Enriching: The Little Mermaid (10144)
# Enriching: Charlie and the Chocolate Factory (118)
# Enriching: Kong: Skull Island (293167)
# Enriching: Classified (1124641)
# Enriching: A Quiet Place (447332)
# Enriching: The Amazing Spider-Man (1930)
# Enriching: Jurassic World: Fallen Kingdom (351286)
# Enriching: Pirates of the Caribbean: At World's End (285)
# Enriching: Pride & Prejudice (4348)
# Enriching: Beauty and the Beast (10020)
# Enriching: Descendants: The Rise of Red (974262)
# Enriching: John Wick (245891)
# Enriching: Real Steel (39254)
# Enriching: Shrek Forever After (10192)
# Enriching: Shrek the Third (810)
# Enriching: The Prestige (1124)
# Enriching: Raya and the Last Dragon (527774)
# Enriching: Me Before You (296096)
# Enriching: It Ends with Us (1079091)
# Enriching: The Imitation Game (205596)
# Enriching: Edge of Tomorrow (137113)
# Enriching: The Tomorrow War (588228)
# Enriching: We Live in Time (1100099)
# Enriching: The Dark Knight Rises (49026)
# Enriching: Inglourious Basterds (16869)
# Enriching: Knives Out (546554)
# Enriching: Ready Player One (333339)
# Enriching: The Idea of You (843527)
# Enriching: Oldboy (670)
# Enriching: Mean Girls (10625)
# Enriching: Everything Everywhere All at Once (545611)
# Enriching: Nacho Libre (9353)
# Enriching: Dragonkeeper (588648)
# Enriching: John Wick: Chapter 2 (324552)
# Enriching: Girl in the Basement (801335)
# Enriching: Past Lives (666277)
# Enriching: Star Wars: The Last Jedi (181808)
# Enriching: Wind River (395834)
# Enriching: A Real Pain (1013850)
# Enriching: Thor: Love and Thunder (616037)
# Enriching: Batman v Superman: Dawn of Justice (209112)
# Enriching: Snowpiercer (110415)
# Enriching: The Hobbit: An Unexpected Journey (49051)
# Enriching: Indiana Jones and the Dial of Destiny (335977)
# Enriching: Grown Ups 2 (109418)
# Enriching: xXx: Return of Xander Cage (47971)
# Enriching: Midsommar (530385)
# Enriching: Through My Window (818647)
# Enriching: Eternals (524434)
# Enriching: Mirrors (13515)
# Enriching: The Final Destination (19912)
# Enriching: Django Unchained (68718)
# Enriching: Arrival (329865)
# Enriching: Troy (652)
# Enriching: The Mummy (564)
# Enriching: Spider-Man: Far From Home (429617)
# Enriching: Strange Darling (1029281)
# Enriching: Iron Man 3 (68721)
# Enriching: Mr. & Mrs. Smith (787)
# Enriching: Meg 2: The Trench (615656)
# Enriching: Land of Bad (969492)
# Enriching: The Twilight Saga: Breaking Dawn - Part 1 (50619)
# Enriching: The Twilight Saga: Eclipse (24021)
# Enriching: 20th Century Girl (851644)
# Enriching: Ghost in the Shell: S.A.C. 2nd GIG - Individual Eleven (111224)
# Enriching: The Hobbit: The Desolation of Smaug (57158)
# Enriching: Jumanji: The Next Level (512200)
# Enriching: The Bad Guys: Haunted Heist (1329336)
# Enriching: Hidden Figures (381284)
# Enriching: Weekend in Taipei (1167271)
# Enriching: Madagascar (953)
# Enriching: The Flash (298618)
# Enriching: The Amazing Spider-Man 2 (102382)
# Enriching: Joker: Folie à Deux (889737)
# Enriching: Soul (508442)
# Enriching: Doctor Strange (284052)
# Enriching: Three Steps Above Heaven (61979)
# Enriching: Get Out (419430)
# Enriching: The Intouchables (77338)
# Enriching: Kung Fu Panda (9502)
# Enriching: Black Widow (497698)
# Enriching: Drawing Closer (1291559)
# Enriching: Expend4bles (299054)
# Enriching: The Forge (1186532)
# Enriching: Final Destination 3 (9286)
# Enriching: Don't Move (1063877)
# Enriching: My Old Ass (947891)
# Enriching: The Naked Gun: From the Files of Police Squad! (37136)
# Enriching: Twilight of the Warriors: Walled In (923667)
# Enriching: Damsel (763215)
# Enriching: The Shining (694)
# Enriching: The Family Plan (1029575)
# Enriching: Turning Red (508947)
# Enriching: The Nun II (968051)
# Enriching: Despicable Me (20352)
# Enriching: The Incredibles (9806)
# Enriching: Kingdom of Heaven (1495)
# Enriching: Canary Black (976734)
# Enriching: Ted 2 (214756)
# Enriching: Kinda Pregnant (1212142)
# Enriching: Catch Me If You Can (640)
# Enriching: X-Men: Days of Future Past (127585)
# Enriching: Mission: Impossible - Fallout (353081)
# Enriching: Thor (10195)
# Enriching: Superbad (8363)
# Enriching: Guardians of the Galaxy Vol. 2 (283995)
# Enriching: Prey (766507)
# Enriching: The Predator (346910)
# Enriching: Once Upon a Time... in Hollywood (466272)
# Enriching: Smile (882598)
# Enriching: Predator (106)
# Enriching: The Social Network (37799)
# Enriching: How to Train Your Dragon 2 (82702)
# Enriching: Trap (1032823)
# Enriching: American Beauty (14)
# Enriching: Tabu (93858)
# Enriching: Aquaman and the Lost Kingdom (572802)
# Enriching: Cars 3 (260514)
# Enriching: Raiders of the Lost Ark (85)
# Enriching: Taken (8681)
# Enriching: Death Note Relight 1: Visions of a God (51482)
# Enriching: No Country for Old Men (6977)
# Enriching: Men, Women & Children (243684)
# Enriching: The Twilight Saga: New Moon (18239)
# Enriching: Zack Snyder's Justice League (791373)
# Enriching: Green Book (490132)
# Enriching: Baywatch (339846)
# Enriching: The Devil Wears Prada (350)
# Enriching: Bad Boys (9737)
# Enriching: Bird (1128752)
# Enriching: The Hunger Games (70160)
# Enriching: Squid Game: Making Season 2 (1412113)
# Enriching: Her (152601)
# Enriching: Venom: Let There Be Carnage (580489)
# Enriching: Mission: Impossible (954)
# Enriching: The Revenant (281957)
# Enriching: Transformers: The Last Knight (335988)
# Enriching: Emilia Pérez (974950)
# Enriching: Brave (62177)
# Enriching: Trolls Band Together (901362)
# Enriching: Black Swan (44214)
# Enriching: Chappie (198184)
# Enriching: 2012 (14161)
# Enriching: The Dark Tower (353491)
# Enriching: Batman Begins (272)
# Enriching: Texas Chainsaw Massacre (632727)
# Enriching: Pirates of the Caribbean: Dead Men Tell No Tales (166426)
# Enriching: Sing 2 (438695)
# Enriching: Blue Lagoon: The Awakening (115290)
# Enriching: Picture This (1204892)
# Enriching: Pacific Rim (68726)
# Enriching: Minions: The Rise of Gru (438148)
# Enriching: The Croods: A New Age (529203)
# Enriching: Terminator Genisys (87101)
# Enriching: Jaws (578)
# Enriching: The Emperor's New Groove (11688)
# Enriching: Eternal Sunshine of the Spotless Mind (38)
# Enriching: American Sniper (190859)
# Enriching: The Conjuring: The Devil Made Me Do It (423108)
# Enriching: Cars 2 (49013)
# Enriching: GTMAX (1171640)
# Enriching: No Time to Die (370172)
# Enriching: The Gangster, the Cop, the Devil (581528)
# Enriching: Under Paris (1001311)
# Enriching: Annihilation (300668)
# Enriching: Late Night with the Devil (938614)
# Enriching: Scream VI (934433)
# Enriching: The Hunger Games: Mockingjay - Part 2 (131634)
# Enriching: Sicario (273481)
# Enriching: The Tearsmith (1127166)
# Enriching: The Fallout (795514)
# Enriching: Longlegs (1226578)
# Enriching: Léon: The Professional (101)
# Enriching: The Princess and the Frog (10198)
# Enriching: The Conjuring 2 (259693)
# Enriching: Braveheart (197)
# Enriching: Extraction (545609)
# Enriching: Cheeky (22705)
# Enriching: John Wick: Chapter 3 - Parabellum (458156)
# Enriching: Logan (263115)
# Enriching: The Thing (1091)
# Enriching: Aladdin (812)
# Enriching: Desire (86331)
# Enriching: The Intern (257211)
# Enriching: Star Wars: The Force Awakens (140607)
# Enriching: The Godfather Part III (242)
# Enriching: After We Fell (744275)
# Enriching: Ghosted (868759)
# Enriching: Transformers: Age of Extinction (91314)
# Enriching: The Hangover Part II (45243)
# Enriching: Dominique (1331375)
# Enriching: Rush Hour (2109)
# Enriching: It (346364)
# Enriching: Do Not Enter (1287717)
# Enriching: Coherence (220289)
# Enriching: Scary Movie (4247)
# Enriching: Luck (585511)
# Enriching: Black Adam (436270)
# Enriching: Babylon (615777)
# Enriching: Pretty Woman (114)
# Enriching: The Incredible Hulk (1724)
# Enriching: Fall (985939)
# Enriching: Aliens (679)
# Enriching: Extraction 2 (697843)
# Enriching: Meet Joe Black (297)
# Enriching: Constantine (561)
# Enriching: It Chapter Two (474350)
# Enriching: Wolfs (877817)
# Enriching: The Nun (439079)
# Enriching: The Pianist (423)
# Enriching: The Doors (10537)
# Enriching: The Creator (670292)
# Enriching: Juror #2 (1106739)
# Enriching: The Watchers (1086747)
# Enriching: Miraculous: Ladybug & Cat Noir, The Movie (496450)
# Enriching: I Am Legend (6479)
# Enriching: Taxi Driver (103)
# Enriching: The Exorcist (9552)
# Enriching: Us (458723)
# Enriching: Napoleon (753342)
# Enriching: Cars (920)
# Enriching: The Fate of the Furious (337339)
# Enriching: The Killer (970347)
# Enriching: Jack Reacher (75780)
# Enriching: Captain Marvel (299537)
# Enriching: Alice in Wonderland (12155)
# Enriching: Guy Ritchie's The Covenant (882569)
# Enriching: Scream (4232)
# Enriching: Watchmen (13183)
# Enriching: Nobody (615457)
# Enriching: The Mask (854)
# Enriching: Kill 'em All 2 (1215162)
# Enriching: Thor: The Dark World (76338)
# Enriching: The Martian (286217)
# Enriching: Through My Window 3: Looking at You (1139566)
# Enriching: Kill Bill: Vol. 1 (24)
# Enriching: Rush (96721)
# Enriching: Maleficent: Mistress of Evil (420809)
# Enriching: Amélie (194)
# Enriching: Eyes Wide Shut (345)
# Enriching: PAW Patrol: The Mighty Movie (893723)
# Enriching: The Secret Life of Walter Mitty (116745)
# Enriching: Evil Dead Rise (713704)
# Enriching: The First Omen (437342)
# Enriching: War of the Worlds (74)
# Enriching: The Boy in the Striped Pyjamas (14574)
# Enriching: Boyka: Undisputed IV (348893)
# Enriching: Hellboy: The Crooked Man (1087822)
# Enriching: Corpse Bride (3933)
# Enriching: Scream (646385)
# Enriching: Kiki's Delivery Service (16859)
# Enriching: Aladdin (420817)
# Enriching: The Suicide Squad (436969)
# Enriching: The Fifth Element (18)
# Enriching: 10 Things I Hate About You (4951)
# Enriching: Alienoid (601796)
# Enriching: Bridge to Terabithia (1265)
# Enriching: The Matrix Reloaded (604)
# Enriching: Frozen II (330457)
# Enriching: The Ministry of Ungentlemanly Warfare (799583)
# Enriching: Bullet Train (718930)
# Enriching: Alita: Battle Angel (399579)
# Enriching: Ice Age: Continental Drift (57800)
# Enriching: Ghostbusters: Frozen Empire (967847)
# Enriching: Dungeons & Dragons: Honor Among Thieves (493529)
# Enriching: Rambo (7555)
# Enriching: Justice League (141052)
# Enriching: The Parent Trap (9820)
# Enriching: Black Hawk Down (855)
# Enriching: Ice Age: Dawn of the Dinosaurs (8355)
# Enriching: Sicario: Day of the Soldado (400535)
# Enriching: Zodiac (1949)
# Enriching: A Silent Voice: The Movie (378064)
# Enriching: In Time (49530)
# Enriching: The Croods (49519)
# Enriching: American Pie (2105)
# Enriching: Percy Jackson & the Olympians: The Lightning Thief (32657)
# Enriching: Kingsman: The Secret Service (207703)
# Enriching: Kill Shot (1134055)
# Enriching: The Shadow Strays (1151949)
# Enriching: Demon Slayer -Kimetsu no Yaiba- The Movie: Mugen Train (635302)
# Enriching: The Karate Kid (1885)
# Enriching: Hercules (11970)
# Enriching: Bad Boys for Life (38700)
# Enriching: The Killer's Game (507241)
# Enriching: Wreck-It Ralph (82690)
# Enriching: Rio (46195)
# Enriching: Shooter (7485)
# Enriching: Toy Story 3 (10193)
# Enriching: Leo (1075794)
# Enriching: Paddington (116149)
# Enriching: Memento (77)
# Enriching: A Beautiful Mind (453)
# Enriching: The Ten Commandments (6844)
# Enriching: The Marvels (609681)
# Enriching: Immaculate (1041613)
# Enriching: A Serbian Film (73861)
# Enriching: The Departed (1422)
# Enriching: The Witch: Part 2. The Other One (615173)
# Enriching: A Haunted House 2 (184345)
# Enriching: Donnie Darko (141)
# Enriching: Gran Turismo (980489)
# Enriching: Penguins of Madagascar (270946)
# Enriching: Number 24 (1222248)
# Enriching: Ted (72105)
# Enriching: Death Note Relight 2: L's Successors (68555)
# Enriching: How to Train Your Dragon: The Hidden World (166428)
# Enriching: Harold and the Purple Crayon (826510)
# Enriching: Passengers (274870)
# Enriching: Blade Runner (78)
# Enriching: Incredibles 2 (260513)
# Enriching: Indiana Jones and the Last Crusade (89)
# Enriching: No Way Up (1096197)
# Enriching: Divergent (157350)
# Enriching: Brothers (616446)
# Enriching: Lucy (240832)
# Enriching: Kung Fu Panda 3 (140300)
# Enriching: The Lorax (73723)
# Enriching: Dead Poets Society (207)
# Enriching: About Time (122906)
# Enriching: That Christmas (645757)
# Enriching: Ocean's Eleven (161)
# Enriching: The Proposal (18240)
# Enriching: 300 (1271)
# Enriching: Pan's Labyrinth (1417)
# Enriching: The Town (23168)
# Enriching: Edward Scissorhands (162)
# Enriching: Uprising (1075676)
# Enriching: The Ice Age Adventures of Buck Wild (774825)
# Enriching: Man of Steel (49521)
# Enriching: Countdown (599975)
# Enriching: Baby Driver (339403)
# Enriching: Megamind (38055)
# Enriching: Lift (955916)
# Enriching: Sing (335797)
# Enriching: Jurassic Park (329)
# Enriching: Toy Story 4 (301528)
# Enriching: The Grand Budapest Hotel (120467)
# Enriching: Tenet (577922)
# Enriching: Upgrade (500664)
# Enriching: Matilda (10830)
# Enriching: 13 Hours: The Secret Soldiers of Benghazi (300671)
# Enriching: A Bug's Life (9487)
# Enriching: Deadpool 2 (383498)
# Enriching: E.T. the Extra-Terrestrial (601)
# Enriching: X-Men: Apocalypse (246655)
# Enriching: (500) Days of Summer (19913)
# Enriching: The Convert (1066262)
# Enriching: Ben-Hur (665)
# Enriching: After Ever Happy (744276)
# Enriching: Tarzan (37135)
# Enriching: I, Robot (2048)
# Enriching: A Walk to Remember (10229)
# Enriching: Maze Runner: The Scorch Trials (294254)
# Enriching: The Silent Hour (1047373)
# Enriching: Palm Springs (587792)
# Enriching: After Everything (820525)
# Enriching: Fantastic Beasts: The Secrets of Dumbledore (338953)
# Enriching: Terrifier 2 (663712)
# Enriching: The Sixth Sense (745)
# Enriching: Batman Forever (414)
# Enriching: 10 Lives (567811)
# Enriching: Mission: Impossible - Rogue Nation (177677)
# Enriching: Dawn of the Planet of the Apes (119450)
# Enriching: Emmanuelle (24402)
# Enriching: Taken 3 (260346)
# Enriching: All Quiet on the Western Front (49046)
# Enriching: Clueless (9603)
# Enriching: Split (381288)
# Enriching: Scouts Guide to the Zombie Apocalypse (273477)
# Enriching: Fifty Shades Darker (341174)
# Enriching: Van Helsing (7131)
# Enriching: Ghostbusters (620)
# Enriching: Hit Man (974635)
# Enriching: A Nightmare on Elm Street (377)
# Enriching: The Great Gatsby (64682)
# Enriching: Legally Blonde (8835)
# Enriching: Men in Black (607)
# Enriching: Portrait of a Lady on Fire (531428)
# Enriching: The Witch (310131)
# Enriching: After We Collided (613504)
# Enriching: The Princess Diaries (9880)
# Enriching: Now You See Me (75656)
# Enriching: El Candidato Honesto (1278099)
# Enriching: All Things Fair (27098)
# Enriching: Guardians of the Galaxy (118340)
# Enriching: No Hard Feelings (884605)
# Enriching: The Mummy Returns (1734)
# Enriching: San Andreas (254128)
# Enriching: Hotel Transylvania (76492)
# Enriching: Flipped (43949)
# Enriching: The Saint (10003)
# Enriching: The Wizard of Oz (630)
# Enriching: Despicable Me 2 (93456)
# Enriching: Rebel Ridge (646097)
# Enriching: Operation Fortune: Ruse de Guerre (739405)
# Enriching: The Simpsons Movie (35)
# Enriching: Ant-Man and the Wasp: Quantumania (640146)
# Enriching: Ice Age: Collision Course (278154)
# Enriching: Uncharted (335787)
# Enriching: Willow (847)
# Enriching: Saw (176)
# Enriching: Kung Fu Panda 2 (49444)
# Enriching: Maze Runner: The Death Cure (336843)
# Enriching: The Greatest Showman (316029)
# Enriching: The Equalizer 2 (345887)
# Enriching: Rush Hour 3 (5174)
# Enriching: Queer (1059128)
# Enriching: Killers of the Flower Moon (466420)
# Enriching: Sherlock Holmes (10528)
# Enriching: Gunner (5492)
# Enriching: Norbit (9757)
# Enriching: The Black Phone (756999)
# Enriching: Pixels (257344)
# Enriching: The Nightmare Before Christmas (9479)
# Enriching: Dark Phoenix (320288)
# Enriching: Rango (44896)
# Enriching: Creed (312221)
# Enriching: Annabelle Comes Home (521029)
# Enriching: Diary of a Nymphomaniac (19173)
# Enriching: Free Guy (550988)
# Enriching: 1917 (530915)
# Enriching: Madagascar 3: Europe's Most Wanted (80321)
# Enriching: Nightcrawler (242582)
# Enriching: Life Is Beautiful (637)
# Enriching: She's Out of My League (34016)
# Enriching: Hotel Transylvania: Transformania (585083)
# Enriching: X (760104)
# Enriching: Challengers (937287)
# Enriching: Creed III (677179)
# Enriching: Notting Hill (509)
# Enriching: Y2K (1094274)
# Enriching: Cruel Intentions (796)
# Enriching: Captain America: The First Avenger (1771)
# Enriching: Ice Age: The Meltdown (950)
# Enriching: The Prince of Egypt (9837)
# Enriching: Wrong Turn 2: Dead End (13186)
# Enriching: The Karate Kid Part II (8856)
# Enriching: Apocalypto (1579)
# Enriching: The SpongeBob SquarePants Movie (11836)
# Enriching: The Pope's Exorcist (758323)
# Enriching: The Matrix Resurrections (624860)
# Enriching: Fantastic Beasts and Where to Find Them (259316)
# Enriching: Megamind vs. the Doom Syndicate (1239251)
# Enriching: Shazam! Fury of the Gods (594767)
# Enriching: Home Alone 2: Lost in New York (772)
# Enriching: The Killer (800158)
# Enriching: Insidious (49018)
# Enriching: Scary Movie 2 (4248)
# Enriching: The Platform (619264)
# Enriching: Rebel Moon - Part Two: The Scargiver (934632)
# Enriching: A Quiet Place Part II (520763)
# Enriching: The Core (9341)
# Enriching: Detective Conan: Black Iron Submarine (1047041)
# Enriching: Creed II (480530)
# Enriching: Spirit: Stallion of the Cimarron (9023)
# Enriching: The Curious Case of Benjamin Button (4922)
# Enriching: Blink Twice (840705)
# Enriching: Jujutsu Kaisen 0 (810693)
# Enriching: The Girl Next Door (10591)
# Enriching: The Bad Guys (629542)
# Enriching: Captain America: The Winter Soldier (100402)
# Enriching: Mulholland Drive (1018)
# Enriching: Downsizing (301337)
# Enriching: Autumn and the Black Jaguar (959098)
# Enriching: The Fabelmans (804095)
# Enriching: Lilo & Stitch 2: Stitch Has a Glitch (20760)
# Enriching: Heart Eyes (1302916)
# Enriching: From Paris with Love (26389)
# Enriching: The Hunt (514847)
# Enriching: Perfect Days (976893)
# Enriching: Teenage Mutant Ninja Turtles (98566)
# Enriching: Terminator Salvation (534)
# Enriching: Orphan (21208)
# Enriching: Gigli (8046)
# Enriching: Murder on the Orient Express (392044)
# Enriching: Star Wars: The Rise of Skywalker (181812)
# Enriching: Batman (268)
# Enriching: The Ballad of Buster Scruggs (537996)
# Enriching: Blended (232672)
# Enriching: The King's Man (476669)
# Enriching: Afraid (1062215)
# Enriching: Atlas (614933)
# Enriching: I Now Pronounce You Chuck & Larry (3563)
# Enriching: Wrong Turn (9902)
# Enriching: Memories of Murder (11423)
# Enriching: Paddington 2 (346648)
# Enriching: Crazy, Stupid, Love. (50646)
# Enriching: Sleeping Beauty (10882)
# Enriching: The Founder (310307)
# Enriching: Spectre (206647)
# Enriching: Enchanted (4523)
# Enriching: Hotel Transylvania 3: Summer Vacation (400155)
# Enriching: Kleks Academy (1026999)
# Enriching: Madame Web (634492)
# Enriching: Ralph Breaks the Internet (404368)
# Enriching: Blue Beetle (565770)
# Enriching: Unfaithful (2251)
# Enriching: Terrifier (420634)
# Enriching: Terminator: Dark Fate (290859)
# Enriching: MaXXXine (1023922)
# Enriching: You're Cordially Invited (996821)
# Enriching: Godzilla: King of the Monsters (373571)
# Enriching: P.O. Box Tinto Brass (55580)
# Enriching: Apocalypse Now (28)
# Enriching: We're the Millers (138832)
# Enriching: Jungle Cruise (451048)
# Enriching: Star Wars: Episode III - Revenge of the Sith (1895)
# Enriching: Life of Pi (87827)
# Enriching: The Little Rascals (10897)
# Enriching: Limitless (51876)
# Enriching: A Man Called Otto (937278)
# Enriching: Ant-Man (102899)
# Enriching: Just Go with It (50546)
# Enriching: The Ritual (433808)
# Enriching: Beverly Hills Cop: Axel F (280180)
# Enriching: The Soul Eater (1084863)
# Enriching: Reservoir Dogs (500)
# Enriching: Honeymoon Crasher (1361622)
# Enriching: The Autopsy of Jane Doe (397243)
# Enriching: The Tunnel to Summer, the Exit of Goodbyes (916192)
# Enriching: Snow White and the Huntsman (58595)
# Enriching: Five Feet Apart (527641)
# Enriching: Mulan (337401)
# Enriching: American Psycho (1359)
# Enriching: The Expendables 3 (138103)
# Enriching: Prometheus (70981)
# Enriching: Irreversible (979)
# Enriching: Look Back (1244492)
# Enriching: Miracle in Cell No. 7 (637920)
# Enriching: F9 (385128)
# Enriching: Monsters vs Aliens (15512)
# Enriching: Dunkirk (374720)
# Enriching: The Expendables (27578)
# Enriching: Don't Be a Menace to South Central While Drinking Your Juice in the Hood (10607)
# Enriching: Mad Max (9659)
# Enriching: Officer Black Belt (1139817)
# Enriching: Beetlejuice (4011)
# Enriching: Love Lies Bleeding (948549)
# Enriching: El Infierno (52629)
# Enriching: Terminator 3: Rise of the Machines (296)
# Enriching: Pearl Harbor (676)
# Enriching: Time Trap (455839)
# Enriching: Wrong Turn 5: Bloodlines (125509)
# Enriching: The Others (1933)
# Enriching: Godzilla (124905)
# Enriching: Back to the Future Part II (165)
# Enriching: The Naked Gun 2½: The Smell of Fear (37137)
# Enriching: Little Man (9072)
# Enriching: Once Upon a Time in America (311)
# Enriching: Jules (1072371)
# Enriching: Rambo: Last Blood (522938)
# Enriching: He's Just Not That Into You (10184)
# Enriching: Thanksgiving (1071215)
# Enriching: Morbius (526896)
# Enriching: Kingsman: The Golden Circle (343668)
# Enriching: Rise of the Planet of the Apes (61791)
# Enriching: It's What's Inside (1052280)
# Enriching: Pinocchio (10895)
# Enriching: The Devil's Advocate (1813)
# Enriching: Superfast! (325358)
# Enriching: Bad Boys II (8961)
# Enriching: Ponyo (12429)
# Enriching: Tropic Thunder (7446)
# Enriching: Sliver (867)
# Enriching: Through My Window: Across the Sea (988078)
# Enriching: Brother Bear (10009)
# Enriching: Alice in Wonderland (12092)
# Enriching: The Hangover Part III (109439)
# Enriching: Blade (36647)
# Enriching: Die Hard (562)
# Enriching: Rise of the Guardians (81188)
# Enriching: A Bronx Tale (1607)
# Enriching: Grease (621)
# Enriching: 2001: A Space Odyssey (62)
# Enriching: District 9 (17654)
# Enriching: Ready or Not (567609)
# Enriching: How to Make Millions Before Grandma Dies (1103621)
# Enriching: HAIKYU!! The Dumpster Battle (1012201)
# Enriching: Rocky (1366)
# Enriching: Monster (1050035)
# Enriching: Casino Royale (36557)
# Enriching: Teenage Mutant Ninja Turtles: Mutant Mayhem (614930)
# Enriching: Once Upon a Time in the West (335)
# Enriching: The Jungle Book (278927)
# Enriching: The Gray Man (725201)
# Enriching: American Made (337170)
# Enriching: My Spy The Eternal City (1048241)
# Enriching: The Magnificent Seven (333484)
# Enriching: Journey 2: The Mysterious Island (72545)
# Enriching: The Babadook (242224)
# Enriching: The Hateful Eight (273248)
# Enriching: Alien: Covenant (126889)
# Enriching: 28 Weeks Later (1562)
# Enriching: Full Metal Jacket (600)
# Enriching: The Hills Have Eyes (9792)
# Enriching: Little Women (331482)
# Enriching: Purple Hearts (762975)
# Enriching: King Kong (254)
# Enriching: Emmanuelle: The Joys of a Woman (28209)
# Enriching: Palmer (458220)
# Enriching: Bohemian Rhapsody (424694)
# Enriching: Shark Tale (10555)
# Enriching: Mission: Impossible - Ghost Protocol (56292)
# Enriching: The Jack in the Box Rises (1207898)
# Enriching: The Exorcism (646683)
# Enriching: Armageddon (95)
# Enriching: She's the Man (9655)
# Enriching: The Boss Baby: Family Business (459151)
# Enriching: Madagascar: Escape 2 Africa (10527)
# Enriching: Skyfall (37724)
# Enriching: Baki Hanma VS Kengan Ashura (1263421)
# Enriching: Top Secret! (8764)
# Enriching: Red Notice (512195)
# Enriching: The Zone of Interest (467244)
# Enriching: Basic Instinct (402)
# Enriching: Fargo (275)
# Enriching: The Shack (345938)
# Enriching: Project X (57214)
# Enriching: The Matrix Revolutions (605)
# Enriching: SPY x FAMILY CODE: White (1062807)
# Enriching: Trouble (1210794)
# Enriching: The Girl with the Dragon Tattoo (65754)
# Enriching: Aquaman (297802)
# Enriching: The Goonies (9340)
# Enriching: Infinite (581726)
# Enriching: Descendants (277217)
# Enriching: The Dreamers (1278)
# Enriching: 6 Underground (509967)
# Enriching: Deep Water (619979)
# Enriching: To All the Boys I've Loved Before (466282)
# Enriching: Weathering with You (568160)
# Enriching: The Gentlemen (522627)
# Enriching: The Call of the Wild (481848)
# Enriching: The Order (1082195)
# Enriching: It Follows (270303)
# Enriching: Mission: Impossible III (956)
# Enriching: Spider-Man 2 (558)
# Enriching: Bruce Almighty (310)
# Enriching: Independence Day (602)
# Enriching: The Invisible Man (570670)
# Enriching: Outside (1306764)
# Enriching: The Big Short (318846)
# Enriching: Colombiana (62835)
# Enriching: Annabelle (250546)
# Enriching: Rebel Moon - Part One: A Child of Fire (848326)
# Enriching: Drive (64690)
# Enriching: Godzilla vs. Kong (399566)
# Enriching: The Lovely Bones (7980)
# Enriching: Superman (1924)
# Enriching: Homefront (204082)
# Enriching: Garfield (8920)
# Enriching: Idiocracy (7512)
# Enriching: Mirror Mirror (62764)
# Enriching: Battleship (44833)
# Enriching: Year One (17610)
# Enriching: Mortal Kombat (460465)
# Enriching: Monsters University (62211)
# Enriching: Sound of Freedom (678512)
# Enriching: Rampage (427641)
# Enriching: Taken 2 (82675)
# Enriching: Woody Woodpecker Goes to Camp (1239146)
# Enriching: Akira (149)
# Enriching: Moonlight (376867)
# Enriching: Virgin Territory (14324)
# Enriching: The Usual Suspects (629)
# Enriching: The Union (704239)
# Enriching: Dirty Dancing (88)
# Enriching: Treasure Planet (9016)
# Enriching: The Kissing Booth (454983)
# Enriching: Indiana Jones and the Temple of Doom (87)
# Enriching: Man on Fire (9509)
# Enriching: The Grinch (360920)
# Enriching: Hulk (1927)
# Enriching: Mission: Impossible II (955)
# Enriching: The Room Next Door (1088514)
# Enriching: Resident Evil: Welcome to Raccoon City (460458)
# Enriching: Escape Plan (107846)
# ✅ Saved batch 1 to movies_batch_1.csv
#
# 🚀 Batch 2: Fetching pages 51 to 100
# Fetching page 51...
# Fetching page 52...
# Fetching page 53...
# Fetching page 54...
# Fetching page 55...
# Fetching page 56...
# Fetching page 57...
# Fetching page 58...
# Fetching page 59...
# Fetching page 60...
# Fetching page 61...
# Fetching page 62...
# Fetching page 63...
# Fetching page 64...
# Fetching page 65...
# Fetching page 66...
# Fetching page 67...
# Fetching page 68...
# Fetching page 69...
# Fetching page 70...
# Fetching page 71...
# Fetching page 72...
# Fetching page 73...
# Fetching page 74...
# Fetching page 75...
# Fetching page 76...
# Fetching page 77...
# Fetching page 78...
# Fetching page 79...
# Fetching page 80...
# Fetching page 81...
# Fetching page 82...
# Fetching page 83...
# Fetching page 84...
# Fetching page 85...
# Fetching page 86...
# Fetching page 87...
# Fetching page 88...
# Fetching page 89...
# Fetching page 90...
# Fetching page 91...
# Fetching page 92...
# Fetching page 93...
# Fetching page 94...
# Fetching page 95...
# Fetching page 96...
# Fetching page 97...
# Fetching page 98...
# Fetching page 99...
# Fetching page 100...
# Enriching: Speed (1637)
# Enriching: The Good Dinosaur (105864)
# Enriching: The Bourne Identity (2501)
# Enriching: The Iron Giant (10386)
# Enriching: Inside Man (388)
# Enriching: City of God (598)
# Enriching: The Chronicles of Narnia: The Voyage of the Dawn Treader (10140)
# Enriching: How to Lose a Guy in 10 Days (9919)
# Enriching: Knox Goes Away (972614)
# Enriching: Brokeback Mountain (142)
# Enriching: Legend (276907)
# Enriching: Sex Tape (225886)
# Enriching: Wrong Turn 3: Left for Dead (23823)
# Enriching: Kill Bill: Vol. 2 (393)
# Enriching: Dennis the Menace (12139)
# Enriching: Angels & Demons (13448)
# Enriching: Gattaca (782)
# Enriching: Hotel Transylvania 2 (159824)
# Enriching: The Expendables 2 (76163)
# Enriching: Upgraded (1014590)
# Enriching: X-Rated: The Greatest Adult Movies of All Time (324558)
# Enriching: The Founder (310307)
# Enriching: The Key (28468)
# Enriching: The Da Vinci Code (591)
# Enriching: 13 Going on 30 (10096)
# Enriching: Exhuma (838209)
# Enriching: The Roundup: No Way Out (955555)
# Enriching: The Secret World of Arrietty (51739)
# Enriching: The Raid (94329)
# Enriching: Meet the Robinsons (1267)
# Enriching: Taken 2 (82675)
# Enriching: Indiana Jones and the Kingdom of the Crystal Skull (217)
# Enriching: The Exorcism (646683)
# Enriching: The Rock (9802)
# Enriching: The Chronicles of Narnia: Prince Caspian (2454)
# Enriching: Gravity (49047)
# Enriching: The Apprentice (1182047)
# Enriching: One Piece Film Red (900667)
# Enriching: Nymphomaniac: Vol. II (249397)
# Enriching: Into the Wild (5915)
# Enriching: Jack the Giant Slayer (81005)
# Enriching: S.W.A.T. (9257)
# Enriching: Scary Movie 3 (4256)
# Enriching: Bambi (3170)
# Enriching: The Thundermans Return (1094556)
# Enriching: The Transporter (4108)
# Enriching: Predestination (206487)
# Enriching: The Jungle Book (9325)
# Enriching: Megalopolis (592831)
# Enriching: Sound of Freedom (678512)
# Enriching: The Great Wall (311324)
# Enriching: Psycho (539)
# Enriching: The Purge (158015)
# Enriching: Predators (34851)
# Enriching: Kleks Academy (1026999)
# Enriching: Freelance (897087)
# Enriching: I Saw the TV Glow (858017)
# Enriching: Justice League: Crisis on Infinite Earths Part Three (1209290)
# Enriching: Mothering Sunday (718838)
# Enriching: Snatch (107)
# Enriching: The SpongeBob Movie: Sponge on the Run (400160)
# Enriching: Ex Machina (264660)
# Enriching: When Evil Lurks (744857)
# Enriching: Shaun of the Dead (747)
# Enriching: Alice in Terrorland (1174618)
# Enriching: Death Race (10483)
# Enriching: V for Vendetta (752)
# Enriching: Fantastic Four (9738)
# Enriching: Valerian and the City of a Thousand Planets (339964)
# Enriching: Dumb and Dumber (8467)
# Enriching: Ninja Assassin (22832)
# Enriching: Castle in the Sky (10515)
# Enriching: The Day of the Jackal (4909)
# Enriching: The Count of Monte Cristo (11362)
# Enriching: The Spiderwick Chronicles (8204)
# Enriching: Stepfather 2 (30666)
# Enriching: Greenland (524047)
# Enriching: 300: Rise of an Empire (53182)
# Enriching: Mirror Mirror (62764)
# Enriching: Escape Plan (107846)
# Enriching: American History X (73)
# Enriching: Death on the Nile (505026)
# Enriching: Creation of the Gods I: Kingdom of Storms (856289)
# Enriching: Pimpinero: Blood and Oil (1326059)
# Enriching: Contact (686)
# Enriching: The Italian Job (9654)
# Enriching: Zombieland (19908)
# Enriching: The Nice Guys (290250)
# Enriching: Manchester by the Sea (334541)
# Enriching: Hounds of War (949484)
# Enriching: Morbius (526896)
# Enriching: Children of Men (9693)
# Enriching: It Boy (173185)
# Enriching: Fantastic Four: Rise of the Silver Surfer (1979)
# Enriching: The Foreigner (379149)
# Enriching: Miss Peregrine's Home for Peculiar Children (283366)
# Enriching: Red, White & Royal Blue (930094)
# Enriching: HAIKYU!! The Dumpster Battle (1012201)
# Enriching: Four Brothers (8292)
# Enriching: Rambo: First Blood Part II (1369)
# Enriching: The Cabin in the Woods (22970)
# Enriching: Spartacus (967)
# Enriching: Annabelle: Creation (396422)
# Enriching: Lost in Translation (153)
# Enriching: The Secret Life of Pets 2 (412117)
# Enriching: Bridget Jones's Diary (634)
# Enriching: Ant-Man and the Wasp (363088)
# Enriching: The Mitchells vs. the Machines (501929)
# Enriching: Harry Potter 20th Anniversary: Return to Hogwarts (899082)
# Enriching: Daredevil (9480)
# Enriching: Jesus (45139)
# Enriching: Nightbitch (728949)
# Enriching: First Blood (1368)
# Enriching: Dumbo (11360)
# Enriching: The Girl with the Dragon Tattoo (65754)
# Enriching: Nope (762504)
# Enriching: Halloween (948)
# Enriching: No manches, Frida 2: paraíso destruido (554596)
# Enriching: American Gangster (4982)
# Enriching: Space Jam: A New Legacy (379686)
# Enriching: Take Cover (1094974)
# Enriching: Me, Myself & Irene (2123)
# Enriching: Before Sunrise (76)
# Enriching: It's a Wonderful Life (1585)
# Enriching: Silent Hill (588)
# Enriching: Jojo Rabbit (515001)
# Enriching: Wonder Woman 1984 (464052)
# Enriching: Shazam! (287947)
# Enriching: Wonder (406997)
# Enriching: RoboCop (5548)
# Enriching: 9 Songs (27)
# Enriching: Kandahar (717930)
# Enriching: Bolt (13053)
# Enriching: Here (940139)
# Enriching: The Six Triple Eight (1061699)
# Enriching: Despicable Me 3 (324852)
# Enriching: Tag (455980)
# Enriching: The Lost City (752623)
# Enriching: The Crow (9495)
# Enriching: Scary Movie 4 (4257)
# Enriching: House of Ga'a (1311550)
# Enriching: Suzume (916224)
# Enriching: Ghost (251)
# Enriching: Airplane! (813)
# Enriching: How to Train Your Dragon: Homecoming (638507)
# Enriching: The Call of the Wild (481848)
# Enriching: Jennifer's Body (19994)
# Enriching: Scary Movie 5 (4258)
# Enriching: Moneyball (60308)
# Enriching: The Last Witch Hunter (274854)
# Enriching: The Last Samurai (616)
# Enriching: Scream 4 (41446)
# Enriching: From Dusk Till Dawn (755)
# Enriching: Rush Hour 2 (5175)
# Enriching: The Girl with the Needle (1232827)
# Enriching: Malena (10867)
# Enriching: Ad Vitam (1261501)
# Enriching: Insidious: The Red Door (614479)
# Enriching: Suicide Squad (297761)
# Enriching: Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn) (495764)
# Enriching: The SpongeBob Movie: Sponge Out of Water (228165)
# Enriching: 3 Idiots (20453)
# Enriching: RRR (579974)
# Enriching: Night Swim (1072342)
# Enriching: Wrong Turn 4: Bloody Beginnings (71672)
# Enriching: Rocky IV (1374)
# Enriching: Hitman: Agent 47 (249070)
# Enriching: Sniper: G.R.I.T. - Global Response & Intelligence Team (1171541)
# Enriching: The Book of Life (228326)
# Enriching: Jupiter Ascending (76757)
# Enriching: A Clockwork Orange (185)
# Enriching: Warcraft (68735)
# Enriching: Disobedience (419743)
# Enriching: Aliens vs Predator: Requiem (440)
# Enriching: Leroy & Stitch (21316)
# Enriching: Ocean's Eight (402900)
# Enriching: Finding Dory (127380)
# Enriching: Now You See Me 2 (291805)
# Enriching: 365 Days (664413)
# Enriching: The Dictator (76493)
# Enriching: Batman Returns (364)
# Enriching: Mavka: The Forest Song (459003)
# Enriching: Mrs. Doubtfire (788)
# Enriching: My Spy The Eternal City (1048241)
# Enriching: The Addams Family (2907)
# Enriching: Coming to America (9602)
# Enriching: 6 Underground (509967)
# Enriching: Journey 2: The Mysterious Island (72545)
# Enriching: The Blue Lagoon (5689)
# Enriching: Ghost in the Shell (9323)
# Enriching: Fallen Angels (11220)
# Enriching: Trouble (1210794)
# Enriching: The Time Traveler's Wife (24420)
# Enriching: Angel Has Fallen (423204)
# Enriching: Ghost Rider (1250)
# Enriching: Lone Survivor (193756)
# Enriching: House of Wax (10066)
# Enriching: Trolls (136799)
# Enriching: Nowhere (1151534)
# Enriching: Burning Betrayal (1173558)
# Enriching: Battleship (44833)
# Enriching: Elysium (68724)
# Enriching: Argylle (848538)
# Enriching: Selena (16052)
# Enriching: The Other Zoey (912916)
# Enriching: Love and Monsters (590223)
# Enriching: The Hunchback of Notre Dame (10545)
# Enriching: A Haunted House (139038)
# Enriching: Teen Wolf: The Movie (877703)
# Enriching: Central Intelligence (302699)
# Enriching: Honeymoon Crasher (1361622)
# Enriching: Lady and the Tramp (10340)
# Enriching: Kill (1160018)
# Enriching: City Hunter (1061990)
# Enriching: Need for Speed (136797)
# Enriching: Thelma the Unicorn (739547)
# Enriching: Secret of the Wings (75258)
# Enriching: In the Realm of the Senses (5879)
# Enriching: Planet of the Apes (871)
# Enriching: The Breakfast Club (2108)
# Enriching: Pacific Rim: Uprising (268896)
# Enriching: Twelve Monkeys (63)
# Enriching: Clash of the Titans (18823)
# Enriching: The Irishman (398978)
# Enriching: Die Hard: With a Vengeance (1572)
# Enriching: Total Recall (861)
# Enriching: Retribution (762430)
# Enriching: Old School (11635)
# Enriching: Love & Other Drugs (43347)
# Enriching: PAW Patrol: The Movie (675445)
# Enriching: The Texas Chain Saw Massacre (30497)
# Enriching: Bird Box (405774)
# Enriching: All the President's Men (891)
# Enriching: Dilwale Dulhania Le Jayenge (19404)
# Enriching: The Jack in the Box Rises (1207898)
# Enriching: Sexual Chronicles of a French Family (112160)
# Enriching: La Dolce Villa (1252377)
# Enriching: Perfume: The Story of a Murderer (1427)
# Enriching: Oblivion (75612)
# Enriching: Star Wars: Episode I - The Phantom Menace (1893)
# Enriching: Triangle (26466)
# Enriching: Hancock (8960)
# Enriching: Exodus: Gods and Kings (147441)
# Enriching: How the Grinch Stole Christmas (8871)
# Enriching: Legends of the Fall (4476)
# Enriching: The Exorcist: Believer (807172)
# Enriching: Jackpot! (1094138)
# Enriching: Pocahontas (10530)
# Enriching: Moonfall (406759)
# Enriching: Dawn of the Dead (924)
# Enriching: The Devil's Bath (931944)
# ...
# Enriching: Novocaine (20794)
# Enriching: Pretty in Pink (11522)
# Enriching: Goodnight Mommy (284303)
# Enriching: Scrooged (9647)
# Enriching: Rurouni Kenshin Part II: Kyoto Inferno (221731)
# Enriching: The Boy, the Mole, the Fox and the Horse (995133)
# Enriching: About Fate (828613)
# Enriching: Funny Games (10234)
# Enriching: Three Colors: Red (110)
# Enriching: Bambi II (13205)
# Enriching: Seven Swords (10703)
# Enriching: Stranger in the Woods (1175038)
# Enriching: Into the Woods (224141)
# Enriching: Time Bandits (36819)
# Enriching: Maquia: When the Promised Flower Blooms (476292)
# Enriching: Bad Genius (455714)
# Enriching: The Gods Must Be Crazy II (11937)
# Enriching: Scooby-Doo! and the Witch's Ghost (17681)
# Enriching: The Delta Force (16113)
# Enriching: Johnny Mnemonic (9886)
# Enriching: Memories (42994)
# Enriching: Obsessed (17335)
# Enriching: One Piece Film: Strong World (41498)
# Enriching: Cinderella Man (921)
# Enriching: All-Time High (1034940)
# Enriching: Child's Play (533642)
# Enriching: Stand by Me Doraemon 2 (728754)
# Enriching: Fireworks (431819)
# Enriching: Miller's Crossing (379)
# Enriching: Piranha 3DD (71668)
# Enriching: Doubt (14359)
# Enriching: Endless Love (19114)
# Enriching: A Cinderella Story: Once Upon a Song (74018)
# Enriching: Police Story 4: First Strike (9404)
# Enriching: My Little Pony: A New Generation (597316)
# Enriching: The Gift (2046)
# Enriching: Dark Skies (145135)
# Enriching: Brick Mansions (254473)
# Enriching: Cold Eyes (204553)
# Enriching: White Boy Rick (438808)
# Enriching: The Taste of Things (964960)
# Enriching: Green Lantern: Beware My Power (887357)
# Enriching: Infinite Storm (811631)
# Enriching: The Getaway (2087)
# Enriching: Innerspace (2614)
# Enriching: Boston Strangler (881164)
# Enriching: Candyman (9529)
# Enriching: Marry Me (615904)
# Enriching: Concussion (321741)
# Enriching: Agora (26428)
# Enriching: Eradication (993867)
# Enriching: Lupin the Third: The Castle of Cagliostro (15371)
# Enriching: Memories of a Teenager (649058)
# Enriching: Odd Thomas (179826)
# Enriching: Hillbilly Elegy (592984)
# Enriching: Draft Day (200505)
# Enriching: A Perfect Getaway (12403)
# Enriching: Straight Outta Nowhere: Scooby-Doo! Meets Courage the Cowardly Dog (843906)
# Enriching: Takers (22907)
# Enriching: Gothika (4970)
# Enriching: Demolition (303991)
# Enriching: Gretel & Hansel (542224)
# Enriching: The King of Staten Island (579583)
# Enriching: 25th Hour (1429)
# Enriching: Secondhand Lions (13156)
# Enriching: Robinson Crusoe (368940)
# Enriching: After Hours (10843)
# Enriching: Nekromantik (11822)
# Enriching: U-571 (3536)
# Enriching: The Three Stooges (76489)
# Enriching: Viking (369698)
# Enriching: The Poseidon Adventure (551)
# Enriching: Death Note (351460)
# Enriching: Detective Conan: Strategy Above the Depths (39204)
# Enriching: Wild Wild West (8487)
# Enriching: Children Who Chase Lost Voices (79707)
# Enriching: A Dangerous Method (48231)
# Enriching: Grimcutty (1024530)
# Enriching: Hail, Caesar! (270487)
# Enriching: How to Be a Latin Lover (425134)
# Enriching: Sinister 2 (283445)
# Enriching: Call Me Chihiro (1024621)
# Enriching: Judas and the Black Messiah (583406)
# Enriching: Tremors: A Cold Day in Hell (496704)
# Enriching: Thunderbolt (10348)
# Enriching: The Gift (328425)
# Enriching: The Finest Hours (300673)
# Enriching: Entergalactic (1027014)
# Enriching: The Legend of the Nahuala (29826)
# Enriching: Brüno (18480)
# Enriching: Stuck on You (1792)
# Enriching: Tremors: Shrieker Island (670266)
# Enriching: Goal! (9763)
# Enriching: The Adventures of Ichabod and Mr. Toad (13465)
# Enriching: Dreamgirls (1125)
# Enriching: The Animatrix (55931)
# Enriching: Pokémon the Movie: Volcanion and the Mechanical Marvel (382190)
# Enriching: Kramer vs. Kramer (12102)
# Enriching: Dumb and Dumberer: When Harry Met Lloyd (10152)
# Enriching: Invincible (11652)
# Enriching: Colors of Evil: Red (1115395)
# Enriching: Green Street Hooligans (8923)
# Enriching: Beasts of No Nation (283587)
# Enriching: An Easy Girl (575479)
# Enriching: The Wrath of Becky (986070)
# Enriching: Jackass Forever (656663)
# Enriching: The 6th Day (8452)
# Enriching: Black Rain (4105)
# Enriching: Shoplifters (505192)
# Enriching: A Prophet (21575)
# Enriching: Smokey and the Bandit (11006)
# Enriching: 1900 (3870)
# Enriching: Role Models (15373)
# Enriching: Elizabeth (4518)
# Enriching: My Spy (592834)
# Enriching: Babel (1164)
# Enriching: The Remains of the Day (1245)
# Enriching: Persona (797)
# Enriching: Underdog (6589)
# Enriching: Breathless (269)
# Enriching: Pink Floyd: The Wall (12104)
# Enriching: The Prince & Me 2: The Royal Wedding (15590)
# Enriching: Batman: The Dark Knight Returns, Part 2 (142061)
# Enriching: The Darjeeling Limited (4538)
# Enriching: Endless Love (226857)
# Enriching: Acts of Vengeance (445954)
# Enriching: Dragonheart 3: The Sorcerer's Curse (300803)
# Enriching: Teen Titans Go! vs. Teen Titans (556901)
# Enriching: Mike and Dave Need Wedding Dates (316023)
# Enriching: Elevator Game (1015303)
# Enriching: Home Alone: The Holiday Heist (134375)
# Enriching: What to Expect When You're Expecting (76494)
# Enriching: In the Tall Grass (523139)
# Enriching: Open Season 2 (13690)
# Enriching: The Green Inferno (171424)
# Enriching: Nowhere to Run (10413)
# Enriching: Antlers (516329)
# Enriching: The Swordsman (492008)
# Enriching: Spontaneous (604578)
# Enriching: The Last Seduction (25284)
# Enriching: Leprechaun Returns (518158)
# Enriching: Beautiful Creatures (109491)
# Enriching: Down (571055)
# Enriching: Mune: Guardian of the Moon (323661)
# Enriching: Aloha (222936)
# Enriching: Smallfoot (446894)
# Enriching: Backcountry (228973)
# Enriching: Perfect Stranger (7183)
# Enriching: I See You (524251)
# Enriching: Foe (760245)
# Enriching: Night of the Living Dead (19185)
# Enriching: Valentine's Day (32856)
# Enriching: Queen of the Damned (11979)
# Enriching: Mr. Harrigan's Phone (723419)
# Enriching: Waiting for Bojangles (851303)
# Enriching: Amber Alert (1248753)
# Enriching: The Exorcist III (11587)
# Enriching: Black Water (454615)
# Enriching: The Cabinet of Dr. Caligari (234)
# Enriching: Rebecca (505379)
# Enriching: The Coffee Table (1056380)
# Enriching: The Postman (9922)
# Enriching: Divaldo Franco (612304)
# Enriching: Apostle (424121)
# Enriching: Barefoot (242042)
# Enriching: Cowboy Bebop: The Movie (11299)
# Enriching: The Bad Guys: A Very Bad Holiday (1046032)
# Enriching: El Dorado (6644)
# Enriching: Broken Arrow (9208)
# Enriching: Gandhi (783)
# Enriching: Bachelor Party (12309)
# Enriching: The King of Comedy (262)
# Enriching: Blame the Game (1172648)
# Enriching: High and Low (12493)
# Enriching: Roma (426426)
# Enriching: The Mauritanian (644583)
# Enriching: I Can Only Imagine (470878)
# Enriching: Kin (425505)
# Enriching: Me Time (862551)
# Enriching: The Searchers (3114)
# Enriching: The Benchwarmers (9957)
# Enriching: Evangelion: 1.0 You Are (Not) Alone (15137)
# Enriching: Cool Hand Luke (903)
# Enriching: Piper (399106)
# Enriching: The Blackout (574982)
# Enriching: The Missing (12146)
# Enriching: Good Night, and Good Luck. (3291)
# Enriching: Red River (3089)
# Enriching: Persuasion (820912)
# Enriching: The Losers (34813)
# Enriching: The Money Pit (10466)
# Enriching: The Wedding Planner (2018)
# Enriching: Tangled: Before Ever After (438747)
# Enriching: The Requin (803114)
# Enriching: The Princess (759175)
# Enriching: Inside Llewyn Davis (86829)
# Enriching: Modern Times (3082)
# Enriching: Duplicity (16558)
# Enriching: Big Time Adolescence (539617)
# Enriching: The Best Offer (152742)
# Enriching: Boiler Room (14181)
# Enriching: The Piano (713)
# Enriching: Paths of Glory (975)
# Enriching: Paranormal Activity: The Ghost Dimension (146301)
# Enriching: Barbie and the Three Musketeers (23566)
# Enriching: Southern Comfort (12528)
# Enriching: The Void (378018)
# Enriching: All Quiet on the Western Front (143)
# Enriching: Get Shorty (8012)
# Enriching: The Prodigy (532671)
# Enriching: I Love You, Beth Cooper (19840)
# Enriching: Ip Man 4: The Finale (449924)
# Enriching: Death Wish (13939)
# Enriching: Notes on a Scandal (1259)
# Enriching: Honey (10028)
# Enriching: Adrift (429300)
# Enriching: Proximity (693158)
# Enriching: Halloween II (24150)
# Enriching: Into the Blue (11968)
# Enriching: Shin Kamen Rider (813477)
# Enriching: Mute (401371)
# Enriching: Inland Empire (1730)
# Enriching: RRRrrrr!!! (21778)
# Enriching: Midway (11422)
# Enriching: Spawn (10336)
# Enriching: The Soccer Football Movie (1037858)
# Enriching: Pandorum (19898)
# Enriching: Diary of a Wimpy Kid: Rodrick Rules (897192)
# Enriching: The Small Victories (1000603)
# Enriching: The Forgotten (10145)
# Enriching: The Tin Drum (659)
# Enriching: David Attenborough: A Life on Our Planet (664280)
# Enriching: Veer-Zaara (4251)
# Enriching: Yojimbo (11878)
# Enriching: King Kong vs. Godzilla (1680)
# Enriching: The Watcher (10685)
# Enriching: My Lucky Stars (10044)
# Enriching: Secret Window (1586)
# Enriching: Dracula 2000 (10577)
# Enriching: Unfriended (277685)
# Enriching: Unfrosted (844185)
# Enriching: Passenger 57 (10538)
# Enriching: A Streetcar Named Desire (702)
# Enriching: The Taking of Pelham 1 2 3 (18487)
# Enriching: New Year's Eve (62838)
# Enriching: Skylines (560144)
# Enriching: Brotherhood of Blades II: The Infernal Battlefield (457837)
# Enriching: Howard the Duck (10658)
# Enriching: Sabotage (144336)
# Enriching: The Beast (914206)
# Enriching: Cry-Baby (9768)
# Enriching: Return of Special Forces 5 (865921)
# Enriching: Dragons: Dawn of the Dragon Racers (298115)
# Enriching: No Reservations (3638)
# Enriching: A Wonderful World (69380)
# Enriching: Evangelion: 2.0 You Can (Not) Advance (22843)
# Enriching: Blood Simple (11368)
# Enriching: Bird on a Wire (1727)
# Enriching: The Entity (24740)
# Enriching: Vantage Point (7461)
# Enriching: Circle (335866)
# Enriching: Stay (8066)
# Enriching: The Silence (60534)
# Enriching: Her Blue Sky (615165)
# Enriching: I'm Not Ashamed (409502)
# Enriching: City Hunter (11198)
# Enriching: The Invisible Guardian (392207)
# Enriching: End of Days (9946)
# Enriching: Ali (8489)
# Enriching: Monolith (408381)
# Enriching: The American President (9087)
# Enriching: Soul Plane (12657)
# Enriching: All the Money in the World (446791)
# Enriching: Crater (620705)
# Enriching: Avatar: Creating the World of Pandora (111332)
# Enriching: Mafia Mamma (809787)
# Enriching: Trial by Fire (481880)
# Enriching: My Own Private Idaho (468)
# Enriching: Popeye (11335)
# Enriching: Reminiscence (579047)
# Enriching: The Cursed (630392)
# Enriching: The Christmas Chronicles: Part Two (654028)
# Enriching: Doors (798141)
# Enriching: Queenpins (628914)
# Enriching: Little Man Tate (11521)
# Enriching: John Q (8470)
# Enriching: Just Married (12090)
# Enriching: Kneecap (1180629)
# Enriching: The Burial (763165)
# Enriching: Cop Land (2142)
# Enriching: State of Play (16995)
# Enriching: Get Him to the Greek (32823)
# Enriching: Tommy Boy (11381)
# Enriching: Police Academy 6: City Under Siege (11895)
# Enriching: Defiance (13813)
# Enriching: The Life of David Gale (11615)
# Enriching: Bend It Like Beckham (455)
# Enriching: Osmosis Jones (12610)
# Enriching: Force of Nature: The Dry 2 (832262)
# Enriching: Isn't It Romantic (449563)
# Enriching: The Babymakers (98066)
# Enriching: Priest (40156)
# Enriching: The Adventures of Robin Hood (10907)
# Enriching: Attack the Block (59678)
# Enriching: The Dirt (327331)
# Enriching: Seobok (586047)
# Enriching: Bicycle Thieves (5156)
# Enriching: The Royal Hotel (944952)
# Enriching: Do the Right Thing (925)
# Enriching: 2:22 (269795)
# Enriching: Young Frankenstein (3034)
# Enriching: The Philadelphia Story (981)
# Enriching: Batman: Year One (69735)
# Enriching: Emma (3573)
# Enriching: Batman vs. Robin (321528)
# Enriching: Freaks (136)
# Enriching: Planet 51 (16866)
# Enriching: The Secret Garden (521034)
# Enriching: I.S.S. (790462)
# Enriching: Puppy Love (1143319)
# Enriching: Barbie in A Mermaid Tale 2 (91342)
# Enriching: Ninja Scroll (14282)
# Enriching: Rounders (10220)
# Enriching: The Aftermath (433502)
# Enriching: Black Dog (1249423)
# Enriching: Masterminds (213681)
# Enriching: I Origins (244267)
# Enriching: Infidelity in Suburbia (451156)
# Enriching: Dhoom 2 (14194)
# Enriching: Life of a King (201550)
# Enriching: Girl with a Pearl Earring (3635)
# Enriching: The Seven Deadly Sins: Cursed by Light (843241)
# Enriching: Redemption Day (767304)
# Enriching: Mazinger Z: Infinity (452970)
# Enriching: Overdrive (404733)
# Enriching: Get the Gringo (80389)
# Enriching: James and the Giant Peach (10539)
# Enriching: The Unforgivable (645886)
# Enriching: Under the Same Moon (32579)
# Enriching: Operation Y and Other Shurik's Adventures (20875)
# Enriching: TMNT (1273)
# Enriching: Gunpowder Milkshake (574060)
# Enriching: 12 Angry Men (12219)
# Enriching: Grave Encounters 2 (134366)
# Enriching: Lost in Space (2157)
# Enriching: White Bird in a Blizzard (157825)
# Enriching: The Hot Spot (14864)
# Enriching: Billy Madison (11017)
# Enriching: Planet Hulk (30675)
# Enriching: Bobby (10741)
# Enriching: Eddie the Eagle (319888)
# Enriching: Swiss Army Man (347031)
# Enriching: Moonwalker (13192)
# Enriching: The Harder They Fall (618162)
# Enriching: Freud's Last Session (1025491)
# Enriching: The War of the Worlds (8974)
# Enriching: They Call Me Trinity (9394)
# Enriching: The Hours (590)
# Enriching: The Awakening (77949)
# Enriching: Problem Child 3 (28601)
# Enriching: Barbarella (8069)
# Enriching: Vampire Hunter D (9463)
# Enriching: Three Colors: White (109)
# Enriching: War (585268)
# Enriching: Playing It Cool (277547)
# Enriching: The Signal (242095)
# Enriching: Detective Conan: The Last Wizard of the Century (28808)
# Enriching: Kingdom 2: Far and Away (961420)
# Enriching: Europa Report (174772)
# Enriching: Savage Grace (10822)
# Enriching: The Cave (9042)
# Enriching: High Noon (288)
# Enriching: Anne of Green Gables (17663)
# Enriching: Session 9 (10972)
# Enriching: Seraphim Falls (13249)
# Enriching: God Is a Bullet (808396)
# Enriching: Collateral Damage (9884)
# Enriching: The Eight Mountains (803700)
# Enriching: Hard Boiled (11782)
# Enriching: Partysaurus Rex (130925)
# Enriching: Thief (11524)
# Enriching: The Frozen Ground (199373)
# Enriching: Battle for Sevastopol (332270)
# Enriching: Taste of Cherry (30020)
# Enriching: Touch of Evil (1480)
# Enriching: The Big Sleep (910)
# Enriching: The Rugrats Movie (14444)
# Enriching: DOA: Dead or Alive (9053)
# Enriching: Somebody I Used to Know (869112)
# Enriching: Dead Man Down (102362)
# Enriching: Holidate (615665)
# Enriching: Raw (393519)
# Enriching: Tootsie (9576)
# Enriching: Dr. Dolittle 2 (10808)
# Enriching: Escape from L.A. (10061)
# Enriching: Slumberland (668461)
# Enriching: One Piece: Baron Omatsuri and the Secret Island (44729)
# Enriching: The Kid (4244)
# Enriching: Z-O-M-B-I-E-S 2 (599521)
# Enriching: Black Water: Abyss (522444)
# Enriching: Cocktail (7520)
# Enriching: Driving Miss Daisy (403)
# Enriching: Anatomy of Hell (2003)
# Enriching: Trespass (70578)
# Enriching: The Time Machine (2134)
# Enriching: Teenage Mutant Ninja Turtles III (1499)
# Enriching: Sword Art Online the Movie – Progressive – Aria of a Starless Night (761898)
# Enriching: Taking Chance (25405)
# Enriching: Old Dads (987917)
# Enriching: The Little Mermaid (385448)
# Enriching: Accident Man (455236)
# Enriching: Riders of Justice (663870)
# Enriching: Shooting Stars (970284)
# Enriching: The 33 (293646)
# Enriching: The Nut Job 2: Nutty by Nature (335777)
# Enriching: Threads (17835)
# Enriching: Wuthering Heights (3084)
# Enriching: The Night Porter (26648)
# Enriching: ¿Quieres ser mi hijo? (1181678)
# Enriching: Bleeding Steel (460648)
# Enriching: Do Revenge (762968)
# Enriching: Next Friday (10471)
# Enriching: Naked (21450)
# Enriching: Just My Luck (10025)
# Enriching: Little Forest (448491)
# Enriching: Tokyo Godfathers (13398)
# Enriching: The Last King of Scotland (1523)
# Enriching: Out of the Furnace (164457)
# Enriching: Swing Girls (36592)
# Enriching: 2067 (528085)
# Enriching: The Adventures of Baron Munchausen (14506)
# Enriching: Om Shanti Om (8079)
# Enriching: Rim of the World (531306)
# Enriching: Delicatessen (892)
# Enriching: Happiest Season (520172)
# Enriching: Loving Pablo (425336)
# Enriching: My Neighbors the Yamadas (16198)
# Enriching: The Quest (9103)
# Enriching: Critters (3980)
# Enriching: Fantasia 2000 (49948)
# Enriching: The Last Exorcism (38358)
# Enriching: Sabrina (11860)
# Enriching: Once Upon a Time in China (10617)
# Enriching: Unfriended: Dark Web (505058)
# ✅ Saved batch 5 to movies_batch_5.csv

# %%
df_all = pd.concat(all_batches, ignore_index=True)
df_all.to_csv("all_movies_combined.csv", index=False)
print("🎉 Combined all batches into all_movies_combined.csv")
# Out:
# 🎉 Combined all batches into all_movies_combined.csv

# %%
df_all
# Out:
#            id                             title  \
# 0      950387                 A Minecraft Movie
# 1     1125899                           Cleaner
# 2      822119  Captain America: Brave New World
# 3     1197306                     A Working Man
# 4     1252309              Ask Me What You Want
# ...       ...                               ...
# 4995    49948                     Fantasia 2000
# 4996    38358                 The Last Exorcism
# 4997    11860                           Sabrina
# 4998    10617         Once Upon a Time in China
# 4999   505058              Unfriended: Dark Web
#
#                                                overview  \
# 0     Four misfits find themselves struggling with o...
# 1     When a group of radical activists take over an...
# 2     After meeting with newly elected U.S. Presiden...
# 3     Levon Cade left behind a decorated military ca...
# 4     After his father's death, Eric Zimmerman trave...
# ...                                                 ...
# 4995  Blending lively music and brilliant animation,...
# 4996  After years of performing “exorcisms” and taki...
# 4997  Sabrina Fairchild, a chauffeur's daughter, gre...
# 4998  Set in late 19th century Canton, this martial ...
# 4999  ​When a 20-something finds a cache of hidden f...
#
#                                     genres  vote_average  vote_count  \
# 0     [Family, Comedy, Adventure, Fantasy]         6.100         295
# 1                       [Action, Thriller]         6.517         174
# 2      [Action, Thriller, Science Fiction]         6.091        1232
# 3                [Action, Crime, Thriller]         6.467         151
# 4                         [Romance, Drama]         5.681         119
# ...                                    ...           ...         ...
# 4995            [Animation, Family, Music]         7.000        1289
# 4996           [Horror, Thriller, Mystery]         5.700        1029
# 4997                      [Romance, Drama]         6.205         642
# 4998                       [Action, Drama]         7.158         427
# 4999           [Horror, Thriller, Mystery]         6.277        1546
#
#      release_date original_language  popularity  adult  runtime     budget  \
# 0      2025-03-31                en   1022.7906  False      101  150000000
# 1      2025-02-19                en    343.3057  False       96          0
# 2      2025-02-12                en    339.0809  False      119  180000000
# 3      2025-03-26                en    293.7838  False      116   40000000
# 4      2024-11-29                es    286.5930  False        0          0
# ...           ...               ...         ...    ...      ...        ...
# 4995   2000-01-01                en      2.5349  False       74   80000000
# 4996   2010-08-27                en      2.5348  False       87    1800000
# 4997   1995-12-15                en      2.5346  False      127   58000000
# 4998   1991-08-15                cn      2.5342  False      133          0
# 4999   2018-07-19                en      2.5340  False       92    1000000
#
#         revenue                                               cast  \
# 0     313453003  [Jason Momoa, Jack Black, Sebastian Eugene Han...
# 1             0  [Daisy Ridley, Clive Owen, Taz Skylar, Flavia ...
# 2     411409721  [Anthony Mackie, Harrison Ford, Danny Ramirez,...
# 3      44417000  [Jason Statham, David Harbour, Michael Peña, J...
# 4             0  [Gabriela Andrada, Mario Ermito, Celia Freijei...
# ...         ...                                                ...
# 4995   60655420  [Steve Martin, Itzhak Perlman, Quincy Jones, B...
# 4996   69400000  [Patrick Fabian, Ashley Bell, Iris Bahr, Louis...
# 4997   53672080  [Harrison Ford, Julia Ormond, Greg Kinnear, Na...
# 4998    3826459  [Jet Li, Yuen Biao, Jacky Cheung, Rosamund Kwa...
# 4999   16000000  [Colin Woodell, Betty Gabriel, Rebecca Rittenh...
#
#              director                                           keywords  \
# 0          Jared Hess  [friendship, surrealism, exploration, portal, ...
# 1     Martin Campbell                                                 []
# 2         Julius Onah  [hero, superhero, revenge, aftercreditsstinger...
# 3          David Ayer  [based on novel or book, kidnapping, vigilante...
# 4       Lucía Alemany  [spain, based on novel or book, woman director...
# ...               ...                                                ...
# 4995      James Algar  [magic, classical music, orchestra, musical, l...
# 4996     Daniel Stamm  [farm, exorcism, louisiana, fraud, mockumentar...
# 4997   Sydney Pollack  [chauffeur, sibling relationship, paris, franc...
# 4998        Tsui Hark  [martial arts, kung fu, hero, china, colonisat...
# 4999    Stephen Susco  [webcam, sequel, lesbian relationship, hacking...
#
#                                              poster_url
# 0     https://image.tmdb.org/t/p/w500/yFHHfHcUgGAxzi...
# 1     https://image.tmdb.org/t/p/w500/mwzDApMZAGeYCE...
# 2     https://image.tmdb.org/t/p/w500/pzIddUEMWhWzfv...
# 3     https://image.tmdb.org/t/p/w500/6FRFIogh3zFnVW...
# 4     https://image.tmdb.org/t/p/w500/76qnVxU2rPdVvi...
# ...                                                 ...
# 4995  https://image.tmdb.org/t/p/w500/5rwAtUaKEK48CP...
# 4996  https://image.tmdb.org/t/p/w500/eOo9tgGjxdsQEg...
# 4997  https://image.tmdb.org/t/p/w500/i8PbLJDPU7vCww...
# 4998  https://image.tmdb.org/t/p/w500/dkBQC0jmkmTOJJ...
# 4999  https://image.tmdb.org/t/p/w500/nOXuOeD07nZPT2...
#
# [5000 rows x 17 columns]
